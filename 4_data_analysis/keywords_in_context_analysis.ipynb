# %% [markdown]
# # Keywords-in-Context (KWIC) Analysis by Theme
#
# This notebook presents a **Keywords-in-Context (KWIC)** analysis across a collection of documents categorized into different thematic areas. The goal is to examine how the most relevant keywords for each theme are used within the actual textual context of the documents.
#
# ### 🔍 Objectives
#
# - Analyze keyword usage contextually within each theme.
# - Surface insights about how critical terms are framed in the data.
#
#
# ### 🧪 Analysis Workflow
#
# 1. **Load and extract text** from PDF files grouped by theme.
# 2. **Preprocess** text by removing non-ASCII characters to ensure clean NLP tokenization.
# 3. **Load top keywords** per theme (previously identified).
# 4. **Perform KWIC analysis** using spaCy to extract left and right context around each keyword.
# 5. **Display results** in a structured table showing:
#    - Left context
#    - Keyword
#    - Right context
#
# ### 📁 Themes Covered
#
# - Barriers to Access
# - Digital Infrastructure
# - Inclusive Digital Technology
# - Tech Ecosystem
# - Case Studies
#
# ---
#
# By comparing how key terms appear across different themes, this notebook enables deeper insights into language patterns and framing within the dataset.

# %% [markdown]
# ### Importing Required Libraries
# In this step, we import essential Python libraries:
# - `pandas` for data manipulation,
# - `fitz` (PyMuPDF) to extract text from PDF documents,
# - `spacy` for natural language processing (NLP) tasks like tokenization.

# %%
import pandas as pd
import fitz
import spacy

# %% [markdown]
# ### Loading the spaCy Language Model
# We load the small English spaCy model `en_core_web_sm`, which will be used to tokenize our text and identify keywords in context.

# %%
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ### Reading PDF Files from Dataset
# Here, we define the dataset folder structure and collect the text data from all PDF files across different thematic folders.
# Each file is tagged with:
# - its name (filename),
# - the theme it belongs to (parent folder name),
# - and the path for accessing its contents.

# %%
from pathlib import Path

# Relative path to the dataset folder
datasets_folder = Path.cwd().parent / "1_datasets"
raw_text_data = []

# Recursively search for all PDF files in subdirectories
for pdf_path in datasets_folder.rglob("*.pdf"):
    raw_text_data.append(
        {
            "name": pdf_path.stem,  # filename without extension
            "theme": pdf_path.parent.name,  # name of the immediate parent folder
            "path": str(pdf_path),  # path to pdf file for later processing
        }
    )

raw_text_data
# Out:
# [{'name': 'Access Denied',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/Access Denied.pdf'},
#  {'name': 'Accessibility to digital technology',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/Accessibility to digital technology.pdf'},
#  {'name': 'Bridging the digital divide',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/Bridging the digital divide.pdf'},
#  {'name': 'ICT and Disability',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/ICT and Disability.pdf'},
#  {'name': 'Mobile Disability Gap Report 2021',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/Mobile Disability Gap Report 2021.pdf'},
#  {'name': 'Social protection and access to assistive technolo',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/Social protection and access to assistive technolo.pdf'},
#  {'name': 'Strengthening ICT Accessibility for PWDs in Africa',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/Strengthening ICT Accessibility for PWDs in Africa.pdf'},
#  {'name': 'The Millions of Nigerians Whose Use of Technology is an Afterthought',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/The Millions of Nigerians Whose Use of Technology is an Afterthought.pdf'},
#  {'name': 'The State of Digital Inclusion in Africa',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/The State of Digital Inclusion in Africa.pdf'},
#  {'name': 'Akinola Opeolu',
#   'theme': 'case_studies',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/case_studies/Akinola Opeolu.pdf'},
#  {'name': 'Farida Bedwei',
#   'theme': 'case_studies',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/case_studies/Farida Bedwei.pdf'},
#  {'name': 'Fredrick Ouko',
#   'theme': 'case_studies',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/case_studies/Fredrick Ouko.pdf'},
#  {'name': 'Innovating Inclusion',
#   'theme': 'case_studies',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/case_studies/Innovating Inclusion.pdf'},
#  {'name': 'Nafisa Baboo',
#   'theme': 'case_studies',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/case_studies/Nafisa Baboo.pdf'},
#  {'name': 'Papi Sibomana',
#   'theme': 'case_studies',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/case_studies/Papi Sibomana.pdf'},
#  {'name': '2024 FinAccess Household Survey',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/2024 FinAccess Household Survey.pdf'},
#  {'name': 'Accelerating digital inclusion in Africa',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/Accelerating digital inclusion in Africa.pdf'},
#  {'name': 'An-Assessment-of-Digital-Inclusion-among-the-Vulnerable-Persons-in-Developing-Economies',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/An-Assessment-of-Digital-Inclusion-among-the-Vulnerable-Persons-in-Developing-Economies.pdf'},
#  {'name': 'Assessing-the-Brriers-to-Accessing-ICT-by-Persons-With-Disabilities-in-Kenya',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/Assessing-the-Brriers-to-Accessing-ICT-by-Persons-With-Disabilities-in-Kenya.pdf'},
#  {'name': 'Digital Transformation Drives Development in Africa',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/Digital Transformation Drives Development in Africa.pdf'},
#  {'name': "fostering Digital Inclusion Among Nigeria's Persons With Disabilities",
#   'theme': 'digital_infrastructure',
#   'path': "/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/fostering Digital Inclusion Among Nigeria's Persons With Disabilities.pdf"},
#  {'name': 'New Insights on Mobile Internet Connectivity in SSA',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/New Insights on Mobile Internet Connectivity in SSA.pdf'},
#  {'name': 'platform Livelihoods For Kenyan Youth With Disabilities,A Survey And Qualitative Study',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/platform Livelihoods For Kenyan Youth With Disabilities,A Survey And Qualitative Study.pdf'},
#  {'name': 'Size and Distribution of Digital Connectivity Gaps in SSA',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/Size and Distribution of Digital Connectivity Gaps in SSA.pdf'},
#  {'name': 'The mobile disability gap,how do persons with disabilities access and use mobile in Kenya and Bangladesh (2)',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/The mobile disability gap,how do persons with disabilities access and use mobile in Kenya and Bangladesh (2).pdf'},
#  {'name': 'Accessibility and Digital Inclusion Knowledge Document',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/Accessibility and Digital Inclusion Knowledge Document.pdf'},
#  {'name': 'AI Assistive Technologies for Persons with Disabilities in Africa',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/AI Assistive Technologies for Persons with Disabilities in Africa.pdf'},
#  {'name': 'AI for Inclusive Development in Africa (AT2030 Report)',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/AI for Inclusive Development in Africa (AT2030 Report).pdf'},
#  {'name': 'Digital Inclusion Practices & Technology Accessibility in Nairobi',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/Digital Inclusion Practices & Technology Accessibility in Nairobi.pdf'},
#  {'name': 'Disability Is Not Inability',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/Disability Is Not Inability.pdf'},
#  {'name': 'Empowering PWD through Digital Innovation',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/Empowering PWD through Digital Innovation.pdf'},
#  {'name': 'How Can AI Assist African Disabled To Be Business Owners and Entrepreneurs',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/How Can AI Assist African Disabled To Be Business Owners and Entrepreneurs.pdf'},
#  {'name': 'Usability and Digital Accessibility Reports',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/Usability and Digital Accessibility Reports.pdf'},
#  {'name': 'Best Practices in the Employment of Persons with Intellectual Disabilities',
#   'theme': 'tech_ecosystem',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/tech_ecosystem/Best Practices in the Employment of Persons with Intellectual Disabilities.pdf'},
#  {'name': 'Empowering Vulnerable Communities',
#   'theme': 'tech_ecosystem',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/tech_ecosystem/Empowering Vulnerable Communities.pdf'},
#  {'name': 'Inside Opeoluwa Akinola’s mission to empower PWD',
#   'theme': 'tech_ecosystem',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/tech_ecosystem/Inside Opeoluwa Akinola’s mission to empower PWD.pdf'},
#  {'name': 'Safaricom PLC Disability Inclusion',
#   'theme': 'tech_ecosystem',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/tech_ecosystem/Safaricom PLC Disability Inclusion.pdf'},
#  {'name': 'Sightsavers Inclusive Data 2024 Annual Review',
#   'theme': 'tech_ecosystem',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/tech_ecosystem/Sightsavers Inclusive Data 2024 Annual Review.pdf'}]

# %% [markdown]
# ### Extracting Text from PDFs
# This function, `extract_text_from_pdf()`, uses PyMuPDF to extract all text from a given PDF file, page by page.
# It will later be applied to each file collected from the dataset.

# %%
def extract_text_from_pdf(pdf_path):
    """
    Extracts all text from a PDF file using PyMuPDF.

    Args:
        pdf_path (str): Path to the PDF file.

    Returns:
        str: Extracted text from the PDF.
    """
    text = ""
    with fitz.open(pdf_path) as doc:
        for page in doc:
            text += page.get_text()
    return text

# %% [markdown]
# ### Applying Text Extraction
# We apply the text extraction function to each file in our dataset.
# If any PDF cannot be processed (e.g., due to corruption), we handle the error gracefully and log the file path for reference.

# %%
for item in raw_text_data:
    try:
        raw = extract_text_from_pdf(item["path"])
        item["text"] = raw
    except Exception as e:
        item["text"] = None
        print(f"Error with {item['path']}: {e}")

# %% [markdown]
# ### Creating Theme-based DataFrames
# Now we create a `DataFrame` from all the text data and split it into separate DataFrames according to their thematic category.
# This allows us to conduct KWIC analysis independently for each theme, such as:
# - Barriers to Access
# - Digital Infrastructure
# - Inclusive Digital Technology
# - Tech Ecosystem
# - Case Studies

# %%
# create a DataFrame from the raw text data
text_datasets_df = pd.DataFrame(raw_text_data, columns=["name", "theme", "text"])

# Create separate dataframes for each thematic category
barrier_to_access = text_datasets_df[
    text_datasets_df["theme"] == "barriers_to_access"
] 
digital_infrastructure = text_datasets_df[
    text_datasets_df["theme"] == "digital_infrastructure"
]  
inclusive_digital_technology = text_datasets_df[
    text_datasets_df["theme"] == "inclusive_digital_technology"
] 
tech_ecosystem = text_datasets_df[
    text_datasets_df["theme"] == "tech_ecosystem"
]  
case_studies = text_datasets_df[text_datasets_df["theme"] == "case_studies"]  # Documents about specific case studies

# %% [markdown]
# ###  Loading Top Keywords by Theme
# We read a CSV file containing the **top 20 extracted keywords** for each theme.
# Then, we split these keywords into separate DataFrames by theme to match the document groups prepared earlier.

# %%
# Gain the top 20 keywords for each thematic category
per_theme_keywords = pd.read_csv( "../1_datasets/processed_data/per_theme_top_keywords.csv",)

# create separate DataFrames for top keywords for each theme
barrier_to_access_keywords = per_theme_keywords[per_theme_keywords["theme"] == "barriers_to_access"]
digital_infrastructure_keywords = per_theme_keywords[per_theme_keywords["theme"] == "digital_infrastructure"]
inclusive_digital_technology_keywords = per_theme_keywords[per_theme_keywords["theme"] == "inclusive_digital_technology"]
tech_ecosystem_keywords = per_theme_keywords[per_theme_keywords["theme"] == "tech_ecosystem"]
case_studies_keywords = per_theme_keywords[per_theme_keywords["theme"] == "case_studies"]

# %% [markdown]
# ### Helper Function to Clean Text
#
# This helper function removes non-ASCII characters from the text. This ensures clean tokenization and prevents issues during spaCy processing.

# %%
def remove_non_ascii(text):
    return text.encode("ascii", errors="ignore").decode("ascii")

# %% [markdown]
# ### Keywords In Context (KWIC) Function Definition
# This function, `kwic_spacy_multiple()`, is at the core of our analysis.
#
# It takes:
# - a list of documents,
# - a list of keywords,
# - and a context window size (default is 7 tokens to the left and right).
#
# For each keyword found in each document, it extracts:
# - the left context (up to N tokens),
# - the keyword itself,
# - and the right context (up to N tokens).
#
# This structure allows us to understand **how keywords are used in different contexts** across documents in a given theme.

# %%
def kwic_spacy_multiple(texts, keywords, window=7):
    tokenized_docs = []
    
    for doc in texts:
        spacy_doc = nlp(doc)
        tokens = [token.text for token in spacy_doc]
        tokenized_docs.append(tokens)
    
    results = []

    for tokens in tokenized_docs:
        for i, token in enumerate(tokens):
            for kw in keywords:
                if token.lower() == kw.lower():
                    left = tokens[max(i - window, 0) : i]
                    right = tokens[i + 1 : i + window + 1]
                    left_str = " ".join(left).replace("\n", " ").strip()
                    right_str = " ".join(right).replace("\n", " ").strip()
                    results.append((kw, left_str, token, right_str))
    return results

# %% [markdown]
# ### KWIC for Barriers to Access Theme
#
# Here we perform KWIC analysis for the "Barriers to Access" theme using:
# - the associated documents (with non-ASCII characters removed),
# - and its top 20 keywords.
#
# The resulting DataFrame (`barrier_to_access_kwic_df`) contains:
# - the keyword,
# - the context to its left and right,
# which will help us qualitatively explore how these keywords are used.

# %%
barrier_to_access_kwic_list = kwic_spacy_multiple(
    barrier_to_access["text"].astype(str).apply(remove_non_ascii).tolist(),
    barrier_to_access_keywords["keyword"].tolist(),
    window=7,
)

barrier_to_access_kwic_df = pd.DataFrame(
    barrier_to_access_kwic_list,
    columns=["Keyword Label", "Left Context", "Keyword", "Right Context"],
)
barrier_to_access_kwic_df.head(50)
# Out:
#    Keyword Label                                       Left Context  \
# 0    development           Sta to Serve Customers with Disabilities
# 1         uganda                Semawata Place , Ntinda   Kampala -
# 2        include                 use to accomplish tasks , and they
# 3          right                      of other rights , such as the
# 4     employment                   such as the right to education ,
# 5       national               their rights must be provided for in
# 6    development         pillars of the 2030 Agenda for Sustainable
# 7      inclusion                     Indeed , up to ve SDGs outline
# 8        include             of persons with disabilities .   These
# 9      inclusive        persons with disabilities .   These include
# 10    employment               ; promotion of full and   productive
# 11     inclusion                ) ; social , economic and political
# 12        uganda                Paul Kimumwe , Kenya , Tanzania and
# 13   development   UN Flagship Report on Disability and Sustainable
# 14   development  No One Behind , https://tinyurl.com/y3ttaxvj  ...
# 15     inclusion  on countries to promote digital accessibility and
# 16        sector            on   governments to ensure that private
# 17         right        into force.11 The Protocol recognises   the
# 18      national                    Moreover , some states in their
# 19   development       contributes to addressing this knowledge and
# 20     inclusion  and communications technology for the empowerm...
# 21   development     contributes to addressing this   knowledge and
# 22      national  Report 2017 ,   http://www.statsbots.org.bw/si...
# 23        uganda  World Disability Report 2011 , https://www.who...
# 24      national                     Uganda18   South Africa19   of
# 25      national                    with disabilities ,    4.2 % of
# 26      national                population   2.87million   7.5 % of
# 27      national                     with disabilities ,   3.5 % of
# 28      national               with disabilities ,   25million   of
# 29        uganda                          MTN and   Vodacom ) , and
# 30        policy  Telecommunications Union ( ITU ) Model Accessi...
# 31        sector          Africa , and assessing public and private
# 32      national  accessibility obligations enshrined in the CRPD ,
# 33        uganda          Africa , New Telecoms Licensing Regime in
# 34        sector  Communications Authority of Kenya , First Quarter
# 35        uganda               Started Operations   1994   Botswana
# 36     inclusive                  use devices with a big keypad and
# 37          case  and inclusive design smartphones.36 Similar to...
# 38      national         . Persons with disabilities from the Joint
# 39      practice                     15(1 ) of the Consumer Code of
# 40        uganda                to manufacturing the devices .   In
# 41        uganda                   in Nairobi . In interviews , MTN
# 42      practice                   Schedule of the Consumer Code of
# 43        uganda               assessed in Botswana , Nigeria , and
# 44   development       Hearing Association.38 It also supported the
# 45      national                  HearZA app , a smartphone - based
# 46        uganda                   There was no evidence   that MTN
# 47        uganda              evidence   that MTN Uganda and Airtel
# 48        policy           companies . It had a guiding procurement
# 49     inclusion                     policy as   part of the groups
#
#         Keyword                                      Right Context
# 0   Development  and Availability of Accessible Applications   ...
# 1        Uganda                www.cipesa.org   Cover , design and
# 2       include     screen   readers , screen magnication software
# 3         right                 to education , employment , social
# 4    employment                , social   services , and political
# 5      national                laws and   policies , and countries
# 6   Development                       Goals ( SDGs ) is the pledge
# 7     inclusion             of persons with disabilities .   These
# 8       include  inclusive learning environments and facilities...
# 9     inclusive       learning environments and facilities ( SDG 4
# 10   employment     that allows persons with disabilities to fully
# 11    inclusion                         ( SDG 10 ) ; creating safe
# 12       Uganda                  Must Do More to Improve Access to
# 13  Development  Goals , https://www.un.org/development/desa/di...
# 14  Development  , https://www.un.org/sustainabledevelopment/  ...
# 15    inclusion    of persons   with disabilities.9 Article 9(2)(g
# 16       sector     service providers also provide information and
# 17        right          of persons with disabilities to barrier -
# 18     national  constitutions guarantee the rights of persons ...
# 19  development              gap by assessing the performance   of
# 20    inclusion              of persons with disabilities , 2019 ,
# 21  development        gap   Disability statistics   for countries
# 22     National           Bureau of Statistics , Number of persons
# 23       Uganda     Bureau of Statistics , Persons With Disability
# 24     national    population   90,945   persons with disabilities
# 25     national                population   2.87million   7.5 % of
# 26     national           population   persons with disabilities ,
# 27     national  population   4.3million   persons with disabil...
# 28     national                  population   6   This pilot study
# 29       Uganda                           ( Airtel and MTN ) . The
# 30       Policy                          2014 , the Web and Mobile
# 31       sector  compliance with digital accessibility obligati...
# 32     national      constitutions and other   relevant policies .
# 33       Uganda  , https://tinyurl.com/yy7ofjex     Ibid .     ...
# 34       Sector  Statistics Report for The Financial Year 2019/...
# 35       Uganda                     South Africa   Nigeria   Kenya
# 36    inclusive          design smartphones.36 Similar to the case
# 37         case                     with MTN South Africa , visits
# 38     National  Association   of Persons Living with Disabilities
# 39     Practice            Regulations 2007 issued by the Nigerian
# 40       Uganda                      , both MTN and Airtel had not
# 41       Uganda           and Safaricom   ocials stated that since
# 42     Practice  Regulation 2007 , https://www.ncc.gov.ng/licen...
# 43       Uganda                          lagging .   None of   the
# 44  development                     of   HearZA app , a smartphone
# 45     national                    hearing test app , developed in
# 46       Uganda   and Airtel Uganda had undertaken any initiatives
# 47       Uganda  had undertaken any initiatives on promoting aw...
# 48       policy                  as   part of the groups inclusion
# 49    inclusion   strategy to ensure accessibility of its services

# %% [markdown]
# ### KWIC for Digital Infrastructure Theme
#
# We now apply the same KWIC analysis process described earlier (see "Barriers to Access") to the **Digital Infrastructure** theme.
#
# This involves:
# - Preprocessing the text (cleaning non-ASCII characters),
# - Using spaCy to tokenize documents,
# - Extracting left and right contexts for the top 20 keywords.
#
# Then explore how keywords are used contextually in this theme’s documents.

# %%
digital_infrastructure_kwic_list = kwic_spacy_multiple(
    digital_infrastructure["text"].astype(str).apply(remove_non_ascii).tolist(),
    digital_infrastructure_keywords["keyword"].tolist(),
    window=7,
)

digital_infrastructure_kwic_df = pd.DataFrame(
    digital_infrastructure_kwic_list,
    columns=["Keyword Label", "Left Context", "Keyword", "Right Context"],
)
digital_infrastructure_kwic_df.head(50)
# Out:
#    Keyword Label                                       Left Context  \
# 0         sector                  5.2    Relevance of the Financial
# 1         policy                          81   7.0   CONCluSiON ANd
# 2      inclusion               7th edition   based on the Financial
# 3      inclusion         quality and impact   dimensions of nancial
# 4      inclusion        like sustainable nance and investment   and
# 5       national                  MBS   Director General ,    Kenya
# 6         sector                  Ms. TaMara CooK   CEO , Financial
# 7      inclusion            to enhance the measurement of   nancial
# 8      inclusion      provide better understanding   of the nancial
# 9      inclusion  inclusion landscape indicators   to track nancial
# 10        policy                   data to support evidence - based
# 11     inclusion                use by stakeholders . The   nancial
# 12        sector               with the   Kenya Vision 2030 nancial
# 13   development             the   Kenya Vision 2030 nancial sector
# 14     inclusive                       ( MTP ) towards achieving an
# 15      national                  ) in collaboration with the Kenya
# 16        sector                  Statistics ( KNBS ) and Financial
# 17     inclusion            members of the   Alliance for Financial
# 18   development        ) and   International Fund for Agricultural
# 19        sector            to encourage   other public and private
# 20        sector     developments in   the rapidly evolving nancial
# 21        sector              widely used by the public and private
# 22        policy          and private sector players   in inuencing
# 23     inclusion   towards nancial deepening and enhanced   nancial
# 24     inclusion                  analysis of the change in nancial
# 25     inclusion         highlight the heterogeneity of the nancial
# 26     inclusion                  of the four dimensions of nancial
# 27        policy        dimensions , provide   rich information for
# 28        sector       rich information for policy makers , private
# 29     inclusion         topline ndings indicate that the   nancial
# 30        sector       services ; government policies , and private
# 31          work                their own charts for quick research
# 32      national                            Kenya   ( CBK ) , Kenya
# 33        sector                Statistics ( KNBS ) and   Financial
# 34        sector       and nancial support from the Joint Financial
# 35     inclusion        questionnaire by the Alliance for Financial
# 36   development          ) ,   International Fund for Agricultural
# 37       include          among   other personnel . Special mention
# 38        sector              involving all facets of the   nancial
# 39      national                  , in partnership with the   Kenya
# 40        sector  Kenya National Bureau of Statistics and Financial
# 41       include         to provide technical   and nancial support
# 42     inclusion           support include ; Alliance for Financial
# 43        sector               Inclusion ( AFI ) , domestic nancial
# 44   development          ) , International Fund for   Agricultural
# 45        sector                        SummAry   K   enyas nancial
# 46        sector                to assess how the benets of nancial
# 47        sector         also investigate   how well Kenyas nancial
# 48        sector                      seeks to nd   out whether the
# 49       include                  and an expanded sample in 2021 to
#
#         Keyword                                      Right Context
# 0        Sector                          in Meeting the Needs   64
# 1        POliCy              rECOmmENdATiONS   85   APPENdix    88
# 2     Inclusion                 Survey . The report provides   key
# 3     inclusion                       . The report also has delved
# 4     Inclusion             for Persons with Disabilities .   2024
# 5      National             Bureau of Statistics   Ms. TaMara CooK
# 6        Sector                  Deepening Trust Kenya   Dr. KaMau
# 7     inclusion            ; provide better understanding   of the
# 8     inclusion  landscape indicators   to track nancial inclusion
# 9     inclusion                 dynamics over time ;   and provide
# 10       policy          formulation and use by stakeholders . The
# 11    inclusion      measurement cuts across the four   dimensions
# 12       sector       development   agenda outlined in the various
# 13  development              agenda outlined in the various Medium
# 14    inclusive               nancial   services ecosystem .   The
# 15     National                  Bureau of Statistics ( KNBS ) and
# 16       Sector                    Deepening Trust ( FSD ) Kenya .
# 17    Inclusion                          ( AFI ) , SACCO Societies
# 18  Development                                 ( IFAD ) . We take
# 19       sector                    players to partner   with us in
# 20       sector                     at the household   level . The
# 21       sector         players   in inuencing policy , strategies
# 22       policy        , strategies , innovations and   supporting
# 23    inclusion                   across the country . Denition of
# 24    inclusion                         at the   county level ( 47
# 25    inclusion         landscape across the counties . Secondly ,
# 26    inclusion              . Emerging issues such as sustainable
# 27       policy                makers , private sector   players ,
# 28       sector              players , investors , researchers and
# 29    inclusion            landscape was impacted by   the various
# 30       sector                 strategies . Indeed , mobile money
# 31         work               and   generate user - specic reports
# 32     National                  Bureau of Statistics ( KNBS ) and
# 33       Sector               Deepening Trust ( FSD Kenya ) taking
# 34       Sector         Regulators Forum comprising of ; Insurance
# 35    Inclusion                    ( AFI ) , United Nations Entity
# 36  Development                        ( IFAD ) ,   Kenya Mortgage
# 37      include                : Rosemary   Okoko , Peter Grivines
# 38       sector        , conducting a FinAccess Household   Survey
# 39     National          Bureau of Statistics and Financial Sector
# 40       Sector                          Deepening ( FSD ) Kenya .
# 41      include             ; Alliance for Financial   Inclusion (
# 42    Inclusion                  ( AFI ) , domestic nancial sector
# 43       sector  regulators ,   Kenya Deposits Insurance Corpor...
# 44  Development                              ( IFAD ) , UN Women ,
# 45       sector                continues to show strong   growth ,
# 46       sector       growth are distributed across the population
# 47       sector          supports its population   in managing day
# 48       sector       is bridging economic and social   inequality
# 49      include                  all   47 counties , have enhanced

# %% [markdown]
# ###  KWIC Analysis for Inclusive Digital Technology Theme
#
# We now apply the same KWIC analysis process described earlier (see "Barriers to Access") to the **Inclusive Digital Technology** theme.
#
# This involves:
# - Preprocessing the text (cleaning non-ASCII characters),
# - Using spaCy to tokenize documents,
# - Extracting left and right contexts for the top 20 keywords.
#
# Then explore how keywords are used contextually in this theme’s documents.

# %%
inclusive_digital_technology_kwic_list = kwic_spacy_multiple(
    inclusive_digital_technology["text"].astype(str).apply(remove_non_ascii).tolist(),
    inclusive_digital_technology_keywords["keyword"].tolist(),
    window=7,
)

inclusive_digital_technology_kwic_df = pd.DataFrame(
    inclusive_digital_technology_kwic_list,
    columns=["Keyword Label", "Left Context", "Keyword", "Right Context"],
)
inclusive_digital_technology_kwic_df.head(50)
# Out:
#    Keyword Label                                       Left Context  \
# 0           work              change the generations to come in the
# 1         sector                      is not   easy and the private
# 2      inclusion                 journey . We will be talking about
# 3       national            Harun Hassan , Executive Director , The
# 4      inclusive            available to people with disabilities .
# 5      inclusive                 the conversation .     The axis of
# 6      inclusive              collaborations , and build networks .
# 7      inclusive            future of innovation in an accessible ,
# 8       training       market , and widespread disability awareness
# 9      inclusion       plays a crucial role in promoting disability
# 10      national                     & Director of Legal Services ,
# 11          work        experiences . Engineers must be involved to
# 12     inclusive                      must be up   to standards and
# 13    employment         disabilities .     Access to education and
# 14    employment        with   disabilities to access education and
# 15        policy  1.Brianna Gilmore ( Moderator)-Head of Accessi...
# 16        policy           Uber   2.Rafael Friedman- Head if Public
# 17      training              wheelchairs . However , investment in
# 18          case                     to access   ticket booths . In
# 19        policy            travel can be improved by engaging with
# 20     inclusive        about technology platforms to create a more
# 21     inclusion    Research Topic : Digital Channels for Financial
# 22      training  Financial institutions lack the necessary data...
# 23      training         them .    People with disabilities require
# 24   development      other people with disabilities , ensuring the
# 25     inclusive         , ensuring the development of disability -
# 26          case        Spiritual Nurture Experiences at Church ; A
# 27          work  congregants should avoid stigmatizing the deaf...
# 28     inclusive    towards acceptance . The church should consider
# 29    employment  Sunday school programs .                      ...
# 30          work        - Getting More persons with disabilities to
# 31    employment      2.Alexander Kojo Tetteh- President Centre for
# 32     inclusion  Takeaways     Microsoft is committed to promoting
# 33     inclusive          develop grant programs and is building an
# 34      training  .     Safaricom is deploying disability awareness
# 35      training       co - creating its curriculum and entrenching
# 36       include            , customers , suppliers , regulators to
# 37      training     persons with   disabilities . Unconscious bias
# 38   development                 , aimed to   improve recruitment ,
# 39    employment  persons with disabilities .                   ...
# 40          work        - Getting More persons with disabilities to
# 41     inclusion  not contemplate any strategy without diversity...
# 42    employment                 Datalead Africa , when it comes to
# 43      training                    b ) skills required , for which
# 44     inclusion      instrumental in bridging the gap . Disability
# 45      training      gap . Disability inclusion and data awareness
# 46      employer                   say you are an equal opportunity
# 47      practice                    employer but actually put it in
# 48     inclusive  level of disability .                         ...
# 49     inclusion     3 . Christine Hemphill- Managing Director Open
#
#         Keyword                                      Right Context
# 0          work                      we   do today in disability .
# 1        sector   should increase motivation on investment . There
# 2     inclusion               in political , social , and economic
# 3      National              Council for   Persons with Disability
# 4     INCLUSIVE         DESIGN WORKSHOP   Rama Gheerawo , Director
# 5     inclusive                  design are age , gender , ability
# 6     Inclusive                  Africa is the type of event where
# 7     inclusive                 , and borderless global   market ,
# 8      training       can contribute to revolutionize technology .
# 9     inclusion           in society . Governments , civil society
# 10     National                      Association of the Deaf , USA
# 11         work                      with , not for , persons with
# 12    inclusive         of persons with disabilities . For example
# 13   employment                      are critical . It is vital to
# 14   employment  opportunities . Children of persons with disab...
# 15       Policy           Uber   2.Rafael Friedman- Head if Public
# 16       Policy            for East Africa Uber   3.John Nalianya-
# 17     training               for drivers on how to handle persons
# 18         case            the person walks in the wrong direction
# 19       policy               regulators to ensure that the entire
# 20    inclusive        environment for persons with disabilities .
# 21    Inclusion        of People with Disabilities ; A Qualitative
# 22     training           to support this group , including making
# 23     training                   in data security and debt / loan
# 24  development    of disability - inclusive products and services
# 25    inclusive  products and services .                       ...
# 26         Case                 of Lugha Ishara   Centre , Nairobi
# 27         work    towards acceptance . The church should consider
# 28    inclusive  Sunday school programs .                      ...
# 29   Employment        - Getting More persons with disabilities to
# 30         work          Speakers   1.Stephen Njenga ( Moderator)-
# 31   Employment          of PWDs   3.Sophie Okonkwo -Senior Talent
# 32    inclusion               in its products and operations . The
# 33    inclusive           tech lab   to test product accessibility
# 34     training                by co - creating its curriculum and
# 35     training             to all programs including products and
# 36      include     persons with   disabilities . Unconscious bias
# 37     training   is delivered across the organization ( including
# 38  development       , and retention of persons with disabilities
# 39   Employment        - Getting More persons with disabilities to
# 40         work                       ( II )    Safaricom does not
# 41    inclusion                           and has set a 5 % target
# 42   employment                        , two things come to play :
# 43     training          deaf people in   becoming instrumental in
# 44    inclusion     and data awareness training among employers in
# 45     training           among employers in   necessary to ensure
# 46     employer                  but actually put it in practice .
# 47     practice  .                                             ...
# 48    Inclusive                 Consumer Research   Speakers   1 .
# 49    Inclusion         Key Takeaways     User experience includes

# %% [markdown]
# ###  KWIC Analysis for Tech EcoSystem Theme
#
# We now apply the same KWIC analysis process described earlier (see "Barriers to Access") to the **Tech EcoSystem** theme.
#
# This involves:
# - Preprocessing the text (cleaning non-ASCII characters),
# - Using spaCy to tokenize documents,
# - Extracting left and right contexts for the top 20 keywords.
#
# Then explore how keywords are used contextually in this theme’s documents.

# %%
tech_ecosystem_kwic_list = kwic_spacy_multiple(
    tech_ecosystem["text"].astype(str).apply(remove_non_ascii).tolist(),
    tech_ecosystem_keywords["keyword"].tolist(),
    window=7,
)

tech_ecosystem_kwic_df = pd.DataFrame(
    tech_ecosystem_kwic_list,
    columns=["Keyword Label", "Left Context", "Keyword", "Right Context"],
)
tech_ecosystem_kwic_df.head(50)  # display top 50 results
# Out:
#    Keyword Label                                       Left Context  \
# 0     employment                              Best Practices in the
# 1   intellectual                  in the Employment of Persons with
# 2           case       Persons with   Intellectual Disabilities : A
# 3         uganda        Intellectual Disabilities : A Case Study of
# 4         uganda                          ,   December 2022       1
# 5      inclusion  Uganda Association for the Mentally Handicapped /
# 6         uganda           for the Mentally Handicapped / Inclusion
# 7     employment                 Uganda       Best Practices in the
# 8   intellectual        Practices in the Employment of Persons with
# 9           case         Persons with Intellectual Disabilities : A
# 10        uganda                   Disabilities : A   Case Study of
# 11    employment  December 2022               Best Practices in the
# 12  intellectual                  in the Employment of Persons with
# 13          case       Persons with   Intellectual Disabilities : A
# 14        uganda        Intellectual Disabilities : A Case Study of
# 15          case                       1 . Executive Summary   This
# 16  intellectual        examines the barriers faced by persons with
# 17    employment  persons with intellectual disabilities in   ac...
# 18        uganda  intellectual disabilities in   accessing emplo...
# 19        sector           : employers from the formal and informal
# 20  intellectual                 and informal sector , persons with
# 21  intellectual                with 25 employers , 25 persons with
# 22      national          review looking at the   international and
# 23        policy        looking at the   international and national
# 24    employment            landscape , and research related to the
# 25  intellectual                to the employment of   persons with
# 26  intellectual    that the major barriers preventing persons with
# 27     inclusive  persons with intellectual disabilities   from ...
# 28    employment  with intellectual disabilities   from finding ...
# 29    employment                  to taking steps to   increase the
# 30  intellectual            increase the employment of persons with
# 31        uganda  employment of persons with intellectual disabi...
# 32    employment  Uganda .                                      ...
# 33  intellectual                  in the Employment of Persons with
# 34          case       Persons with   Intellectual Disabilities : A
# 35        uganda        Intellectual Disabilities : A Case Study of
# 36    employment                6   3.1   International Policies on
# 37      national  on Employment ...................................
# 38    employment                     6   3.2   National Policies on
# 39    employment  .................................................
# 40        uganda      on Employment of Persons with Disabilities in
# 41  intellectual             3.4   Challenges Faced by Persons with
# 42  intellectual                 4.4   Perspectives of Persons with
# 43  intellectual                        13   5.3   For Persons with
# 44        policy  Disabilities ....................................
# 45    employment  .................................................
# 46  intellectual                  in the Employment of Persons with
# 47          case       Persons with   Intellectual Disabilities : A
# 48        uganda        Intellectual Disabilities : A Case Study of
# 49    employment                               4   2 . Introduction
#
#          Keyword                                      Right Context
# 0     Employment      of Persons with   Intellectual Disabilities :
# 1   Intellectual              Disabilities : A Case Study of Uganda
# 2           Case                  Study of Uganda ,   December 2022
# 3         Uganda                          ,   December 2022       1
# 4         Uganda  Association for the Mentally Handicapped / Inc...
# 5      Inclusion                 Uganda       Best Practices in the
# 6         Uganda                Best Practices in the Employment of
# 7     Employment      of Persons with Intellectual Disabilities : A
# 8   Intellectual                   Disabilities : A   Case Study of
# 9           Case                    Study of Uganda     Prepared by
# 10        Uganda                       Prepared by    Aida Nanyonjo
# 11    Employment      of Persons with   Intellectual Disabilities :
# 12  Intellectual              Disabilities : A Case Study of Uganda
# 13          Case                  Study of Uganda ,   December 2022
# 14        Uganda                          ,   December 2022       2
# 15          case        study report examines the barriers faced by
# 16  intellectual   disabilities in   accessing employment in Uganda
# 17    employment         in Uganda . The study employed qualitative
# 18        Uganda        . The study employed qualitative methods of
# 19        sector     , persons with   Intellectual disabilities and
# 20  Intellectual    disabilities and their Parents/ guardians . The
# 21  intellectual     disabilities and 30 parents and/or guardians .
# 22      national         policy landscape , and research related to
# 23        policy            landscape , and research related to the
# 24    employment      of   persons with intellectual disabilities ;
# 25  intellectual           disabilities ; a summary of the research
# 26  intellectual  disabilities   from finding inclusive employme...
# 27     inclusive               employment are a lack of education ,
# 28    employment                   are a lack of education , social
# 29    employment  of persons with intellectual disabilities in U...
# 30  intellectual  disabilities in Uganda .                      ...
# 31        Uganda  .                                      Best Pr...
# 32    Employment      of Persons with   Intellectual Disabilities :
# 33  Intellectual              Disabilities : A Case Study of Uganda
# 34          Case                  Study of Uganda ,   December 2022
# 35        Uganda                          ,   December 2022       3
# 36    Employment  .................................................
# 37      National  Policies on Employment ..........................
# 38    Employment  .................................................
# 39    Employment  of Persons with Disabilities in Uganda ..........
# 40        Uganda  ................................ 8   3.4   Cha...
# 41  Intellectual  Disabilities ....................................
# 42  Intellectual  Disabilities ....................................
# 43  Intellectual  Disabilities ....................................
# 44        Policy  Makers ..........................................
# 45    Employment      of Persons with   Intellectual Disabilities :
# 46  Intellectual              Disabilities : A Case Study of Uganda
# 47          Case                  Study of Uganda ,   December 2022
# 48        Uganda                          ,   December 2022       4
# 49    Employment                        in Uganda is life , but why

# %% [markdown]
# ###  KWIC Analysis for Case Studies Theme
#
# We now apply the same KWIC analysis process described earlier (see "Barriers to Access") to the **Case Studies** theme.
#
# This involves:
# - Preprocessing the text (cleaning non-ASCII characters),
# - Using spaCy to tokenize documents,
# - Extracting left and right contexts for the top 20 keywords.
#
# Then explore how keywords are used contextually in this theme’s documents.

# %%
case_studies_kwic_list = kwic_spacy_multiple(
    case_studies["text"].astype(str).apply(remove_non_ascii).tolist(),
    case_studies_keywords["keyword"].tolist(),
    window=7,
)

case_studies_kwic_df = pd.DataFrame(
    case_studies_kwic_list,
    columns=["Keyword Label", "Left Context", "Keyword", "Right Context"],
)
case_studies_kwic_df.head(50)  # display top 50 results
# Out:
#    Keyword Label                                       Left Context  \
# 0       training        former Pacelli student leads digital skills
# 1        akinola                Care     Years ago , Opeolu Stephen
# 2       training  through   assistive technology and digital skills
# 3      inclusion     former member of several global disability and
# 4      inclusive                 the digital world is becoming more
# 5      inclusive       opening discussions about the   potential of
# 6       national             her appointment to the Board of Ghanas
# 7           case           Unlocking Human Potential   Innovate Now
# 8        include   individuals with disabilities . Their   services
# 9       training  services include providing disability mainstre...
# 10     inclusion                    , and   myths that hinder their
# 11    employment            , faced diculties while searching   for
# 12    employment                   of   narrowing the divide in the
# 13        sector             narrowing the divide in the employment
# 14     inclusion            to nd suitable candidates ,   promoting
# 15    employment              , Fredrick   aimed to oer substantial
# 16      training    rened its distribution methods and   introduced
# 17     inclusive  enlightening   businesses about the signicance of
# 18         skill             seekers can input their qualications ,
# 19      employer                   with potential employers . If an
# 20      training        acquired . Riziki Source places emphasis on
# 21     inclusive           , thereby   ensuring their readiness for
# 22    employment   thereby   ensuring their readiness for inclusive
# 23      training    .. The organization has successfully   provided
# 24      training            the company   has conducted soft skills
# 25    employment  2,000 job seekers    facilitating internships and
# 26     inclusive         these eorts are   geared towards promoting
# 27         right             The company with pitching condence and
# 28     inclusive                       as a   shining example of an
# 29     inclusive           all .   Challenges experienced   Limited
# 30      training    company depends on revenue from recruitment and
# 31        sector            lives of people with disabilities , the
# 32          work             lives but also reshaping the future of
# 33     inclusion                                         Innovating
# 34     inclusive  transforming the landscape   of entrepreneursh...
# 35     inclusive               Technology , from assistive tools to
# 36     inclusive                  and actionable steps   for a more
# 37     inclusive   venture capital globally   supports disability -
# 38     inclusive       entrepreneurs to   navigate digital spaces .
# 39          work   platforms like Upwork and LinkedIn enable remote
# 40      training        , such as virtual reality for accessibility
# 41     inclusion            Global frameworks provide a roadmap for
# 42          work                  27 ,   emphasizes equal access to
# 43   development         digital products by 2025 . The Sustainable
# 44          work                           closely : SDG 8 ( Decent
# 45     inclusive         Decent Work and Economic Growth ) promotes
# 46    employment           and Economic Growth ) promotes inclusive
# 47     inclusion  Reduced Inequalities ) explicitly targets disa...
# 48     inclusion      inclusion . Programs like the ILOs Disability
# 49          work        run her accessibility consulting firm . Her
#
#         Keyword                                      Right Context
# 0      training                    for Y'ello Care     Years ago ,
# 1       Akinola         walked the corridors of the Pacelli School
# 2      training               .     Since launching in August 2023
# 3     inclusion                 bodies , including the World Blind
# 4     inclusive                    . He urged the students to take
# 5     inclusive              technology .   Other MTN leaders also
# 6      National           Communication Authority . Today , Farida
# 7          Case                 study   Founded by Fredrick Ouko ,
# 8       include  providing disability mainstreaming   training ...
# 9      training        and raising awareness among companies   and
# 10    inclusion                 in   workplaces worldwide . One of
# 11   employment                         . As a young graduate , he
# 12   employment    sector by linking individuals with disabilities
# 13       sector     by linking individuals with disabilities   who
# 14    inclusion                 and diversity in the   workforce .
# 15   employment        prospects for disabled individuals in Kenya
# 16     training  programs aimed at enlightening   businesses about
# 17    inclusive                   emplo-   yment practices .   How
# 18        skill                  set , location ,   and disability
# 19     employer         shows interest in a particular candidate ,
# 20     training        employers who have demonstrated an interest
# 21    inclusive       employment   practices ..     Additionally ,
# 22   employment             practices ..     Additionally , Riziki
# 23     training                   to 115   employers and currently
# 24     training  for 2,000 job seekers    facilitating internships
# 25   employment     opportunities   as part of its accomplishments
# 26    inclusive          hiring practices .   Fundraising   Riziki
# 27        right                documentation   obtained a $ 30,000
# 28    inclusive         workspace , showcasing the positive impact
# 29    inclusive       employers : Riziki Source depends on forward
# 30     training          services to sustain its    operations and
# 31       sector      's limited commercial   viability arises from
# 32         work                                                  .
# 33    Inclusion            : Youth with Disabilities   Leading the
# 34    inclusive           innovation and accessible   technology .
# 35    inclusive         digital platforms , is dismantling   these
# 36    inclusive  entrepreneurial ecosystem .   Challenges Facin...
# 37    inclusive   startups , according to the International Labour
# 38    Inclusive       design ensures accessibilitytake the Be   My
# 39         work                          ,   critical for the 15 %
# 40     training                    or 3D - printed   prosthetics ,
# 41    inclusion                       . The UN Convention on   the
# 42         work        and entrepreneurship . Countries like those
# 43  Development                     Goals ( SDGs ) align   closely
# 44         Work           and Economic Growth ) promotes inclusive
# 45    inclusive                        employment , while SDG 10 (
# 46   employment              , while SDG 10 ( Reduced Inequalities
# 47    inclusion      . Programs like the ILOs Disability Inclusion
# 48    Inclusion  Strategy and UNESCOs   youth entrepreneurship ...
# 49         work           trains companies like   Google to design
