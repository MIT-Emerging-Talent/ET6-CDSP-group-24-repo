# %% [markdown]
# # Keywords-in-Context (KWIC) Analysis by Theme
#
# This notebook presents a **Keywords-in-Context (KWIC)** analysis across a collection of documents categorized into different thematic areas. The goal is to examine how the most relevant keywords for each theme are used within the actual textual context of the documents.
#
# ### 🔍 Objectives
#
# - Analyze keyword usage contextually within each theme.
# - Surface insights about how critical terms are framed in the data.
#
#
# ### 🧪 Analysis Workflow
#
# 1. **Load and extract text** from PDF files grouped by theme.
# 2. **Preprocess** text by removing non-ASCII characters to ensure clean NLP tokenization.
# 3. **Load top keywords** per theme (previously identified).
# 4. **Perform KWIC analysis** using spaCy to extract left and right context around each keyword.
# 5. **Display results** in a structured table showing:
#    - Left context
#    - Keyword
#    - Right context
#
# ### 📁 Themes Covered
#
# - Barriers to Access
# - Digital Infrastructure
# - Inclusive Digital Technology
# - Tech Ecosystem
# - Case Studies
#
# ---
#
# By comparing how key terms appear across different themes, this notebook enables deeper insights into language patterns and framing within the dataset.

# %% [markdown]
# ### Importing Required Libraries
# In this step, we import essential Python libraries:
# - `pandas` for data manipulation,
# - `fitz` (PyMuPDF) to extract text from PDF documents,
# - `spacy` for natural language processing (NLP) tasks like tokenization.

# %%
import pandas as pd
import fitz
import spacy

# %% [markdown]
# ### Loading the spaCy Language Model
# We load the small English spaCy model `en_core_web_sm`, which will be used to tokenize our text and identify keywords in context.

# %%
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ### Reading PDF Files from Dataset
# Here, we define the dataset folder structure and collect the text data from all PDF files across different thematic folders.
# Each file is tagged with:
# - its name (filename),
# - the theme it belongs to (parent folder name),
# - and the path for accessing its contents.

# %%
from pathlib import Path

# Relative path to the dataset folder
datasets_folder = Path.cwd().parent / "1_datasets"
raw_text_data = []

# Recursively search for all PDF files in subdirectories
for pdf_path in datasets_folder.rglob("*.pdf"):
    raw_text_data.append(
        {
            "name": pdf_path.stem,  # filename without extension
            "theme": pdf_path.parent.name,  # name of the immediate parent folder
            "path": str(pdf_path),  # path to pdf file for later processing
        }
    )

raw_text_data
# Out:
# [{'name': 'Access Denied',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/Access Denied.pdf'},
#  {'name': 'Accessibility to digital technology',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/Accessibility to digital technology.pdf'},
#  {'name': 'Bridging the digital divide',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/Bridging the digital divide.pdf'},
#  {'name': 'ICT and Disability',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/ICT and Disability.pdf'},
#  {'name': 'Mobile Disability Gap Report 2021',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/Mobile Disability Gap Report 2021.pdf'},
#  {'name': 'Social protection and access to assistive technolo',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/Social protection and access to assistive technolo.pdf'},
#  {'name': 'Strengthening ICT Accessibility for PWDs in Africa',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/Strengthening ICT Accessibility for PWDs in Africa.pdf'},
#  {'name': 'The Millions of Nigerians Whose Use of Technology is an Afterthought',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/The Millions of Nigerians Whose Use of Technology is an Afterthought.pdf'},
#  {'name': 'The State of Digital Inclusion in Africa',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/The State of Digital Inclusion in Africa.pdf'},
#  {'name': 'Akinola Opeolu',
#   'theme': 'case_studies',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/case_studies/Akinola Opeolu.pdf'},
#  {'name': 'Farida Bedwei',
#   'theme': 'case_studies',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/case_studies/Farida Bedwei.pdf'},
#  {'name': 'Fredrick Ouko',
#   'theme': 'case_studies',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/case_studies/Fredrick Ouko.pdf'},
#  {'name': 'Innovating Inclusion',
#   'theme': 'case_studies',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/case_studies/Innovating Inclusion.pdf'},
#  {'name': 'Nafisa Baboo',
#   'theme': 'case_studies',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/case_studies/Nafisa Baboo.pdf'},
#  {'name': 'Papi Sibomana',
#   'theme': 'case_studies',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/case_studies/Papi Sibomana.pdf'},
#  {'name': '2024 FinAccess Household Survey',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/2024 FinAccess Household Survey.pdf'},
#  {'name': 'Accelerating digital inclusion in Africa',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/Accelerating digital inclusion in Africa.pdf'},
#  {'name': 'An-Assessment-of-Digital-Inclusion-among-the-Vulnerable-Persons-in-Developing-Economies',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/An-Assessment-of-Digital-Inclusion-among-the-Vulnerable-Persons-in-Developing-Economies.pdf'},
#  {'name': 'Assessing-the-Brriers-to-Accessing-ICT-by-Persons-With-Disabilities-in-Kenya',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/Assessing-the-Brriers-to-Accessing-ICT-by-Persons-With-Disabilities-in-Kenya.pdf'},
#  {'name': 'Digital Transformation Drives Development in Africa',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/Digital Transformation Drives Development in Africa.pdf'},
#  {'name': "fostering Digital Inclusion Among Nigeria's Persons With Disabilities",
#   'theme': 'digital_infrastructure',
#   'path': "/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/fostering Digital Inclusion Among Nigeria's Persons With Disabilities.pdf"},
#  {'name': 'New Insights on Mobile Internet Connectivity in SSA',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/New Insights on Mobile Internet Connectivity in SSA.pdf'},
#  {'name': 'platform Livelihoods For Kenyan Youth With Disabilities,A Survey And Qualitative Study',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/platform Livelihoods For Kenyan Youth With Disabilities,A Survey And Qualitative Study.pdf'},
#  {'name': 'Size and Distribution of Digital Connectivity Gaps in SSA',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/Size and Distribution of Digital Connectivity Gaps in SSA.pdf'},
#  {'name': 'The mobile disability gap,how do persons with disabilities access and use mobile in Kenya and Bangladesh (2)',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/The mobile disability gap,how do persons with disabilities access and use mobile in Kenya and Bangladesh (2).pdf'},
#  {'name': 'Accessibility and Digital Inclusion Knowledge Document',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/Accessibility and Digital Inclusion Knowledge Document.pdf'},
#  {'name': 'AI Assistive Technologies for Persons with Disabilities in Africa',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/AI Assistive Technologies for Persons with Disabilities in Africa.pdf'},
#  {'name': 'AI for Inclusive Development in Africa (AT2030 Report)',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/AI for Inclusive Development in Africa (AT2030 Report).pdf'},
#  {'name': 'Digital Inclusion Practices & Technology Accessibility in Nairobi',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/Digital Inclusion Practices & Technology Accessibility in Nairobi.pdf'},
#  {'name': 'Disability Is Not Inability',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/Disability Is Not Inability.pdf'},
#  {'name': 'Empowering PWD through Digital Innovation',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/Empowering PWD through Digital Innovation.pdf'},
#  {'name': 'How Can AI Assist African Disabled To Be Business Owners and Entrepreneurs',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/How Can AI Assist African Disabled To Be Business Owners and Entrepreneurs.pdf'},
#  {'name': 'Usability and Digital Accessibility Reports',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/Usability and Digital Accessibility Reports.pdf'},
#  {'name': 'Best Practices in the Employment of Persons with Intellectual Disabilities',
#   'theme': 'tech_ecosystem',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/tech_ecosystem/Best Practices in the Employment of Persons with Intellectual Disabilities.pdf'},
#  {'name': 'Empowering Vulnerable Communities',
#   'theme': 'tech_ecosystem',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/tech_ecosystem/Empowering Vulnerable Communities.pdf'},
#  {'name': 'Inside Opeoluwa Akinola’s mission to empower PWD',
#   'theme': 'tech_ecosystem',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/tech_ecosystem/Inside Opeoluwa Akinola’s mission to empower PWD.pdf'},
#  {'name': 'Safaricom PLC Disability Inclusion',
#   'theme': 'tech_ecosystem',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/tech_ecosystem/Safaricom PLC Disability Inclusion.pdf'},
#  {'name': 'Sightsavers Inclusive Data 2024 Annual Review',
#   'theme': 'tech_ecosystem',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/tech_ecosystem/Sightsavers Inclusive Data 2024 Annual Review.pdf'}]

# %% [markdown]
# ### Extracting Text from PDFs
# This function, `extract_text_from_pdf()`, uses PyMuPDF to extract all text from a given PDF file, page by page.
# It will later be applied to each file collected from the dataset.

# %%
def extract_text_from_pdf(pdf_path):
    """
    Extracts all text from a PDF file using PyMuPDF.

    Args:
        pdf_path (str): Path to the PDF file.

    Returns:
        str: Extracted text from the PDF.
    """
    text = ""
    with fitz.open(pdf_path) as doc:
        for page in doc:
            text += page.get_text()
    return text

# %% [markdown]
# ### Applying Text Extraction
# We apply the text extraction function to each file in our dataset.
# If any PDF cannot be processed (e.g., due to corruption), we handle the error gracefully and log the file path for reference.

# %%
for item in raw_text_data:
    try:
        raw = extract_text_from_pdf(item["path"])
        item["text"] = raw
    except Exception as e:
        item["text"] = None
        print(f"Error with {item['path']}: {e}")

# %% [markdown]
# ### Creating Theme-based DataFrames
# Now we create a `DataFrame` from all the text data and split it into separate DataFrames according to their thematic category.
# This allows us to conduct KWIC analysis independently for each theme, such as:
# - Barriers to Access
# - Digital Infrastructure
# - Inclusive Digital Technology
# - Tech Ecosystem
# - Case Studies

# %%
# create a DataFrame from the raw text data
text_datasets_df = pd.DataFrame(raw_text_data, columns=["name", "theme", "text"])

# Create separate dataframes for each thematic category
barrier_to_access = text_datasets_df[text_datasets_df["theme"] == "barriers_to_access"]
digital_infrastructure = text_datasets_df[
    text_datasets_df["theme"] == "digital_infrastructure"
]
inclusive_digital_technology = text_datasets_df[
    text_datasets_df["theme"] == "inclusive_digital_technology"
]
tech_ecosystem = text_datasets_df[text_datasets_df["theme"] == "tech_ecosystem"]
case_studies = text_datasets_df[
    text_datasets_df["theme"] == "case_studies"
]  # Documents about specific case studies

# %% [markdown]
# ###  Loading Top Keywords by Theme
# We read a CSV file containing the **top 20 extracted keywords** for each theme.
# Then, we split these keywords into separate DataFrames by theme to match the document groups prepared earlier.

# %%
# Gain the top 20 keywords for each thematic category
per_theme_keywords = pd.read_csv(
    "../1_datasets/processed_data/per_theme_top_keywords.csv",
)

# create separate DataFrames for top keywords for each theme
barrier_to_access_keywords = per_theme_keywords[
    per_theme_keywords["theme"] == "barriers_to_access"
]
digital_infrastructure_keywords = per_theme_keywords[
    per_theme_keywords["theme"] == "digital_infrastructure"
]
inclusive_digital_technology_keywords = per_theme_keywords[
    per_theme_keywords["theme"] == "inclusive_digital_technology"
]
tech_ecosystem_keywords = per_theme_keywords[
    per_theme_keywords["theme"] == "tech_ecosystem"
]
case_studies_keywords = per_theme_keywords[
    per_theme_keywords["theme"] == "case_studies"
]
barrier_to_access_keywords.head(20)
# Out:
#                  theme        keyword     score
# 0   barriers_to_access         access  0.348421
# 1   barriers_to_access  accessibility  0.301716
# 2   barriers_to_access     accessible  0.144786
# 3   barriers_to_access      assistive  0.126104
# 4   barriers_to_access        barrier  0.124236
# 5   barriers_to_access  communication  0.137313
# 6   barriers_to_access        country  0.122368
# 7   barriers_to_access         device  0.119565
# 8   barriers_to_access        digital  0.492273
# 9   barriers_to_access            gap  0.119565
# 10  barriers_to_access            ict  0.223251
# 11  barriers_to_access        include  0.137313
# 12  barriers_to_access       internet  0.259681
# 13  barriers_to_access         mobile  0.303584
# 14  barriers_to_access           need  0.126104
# 15  barriers_to_access          rural  0.137313
# 16  barriers_to_access        service  0.226053
# 17  barriers_to_access         social  0.135445
# 18  barriers_to_access     technology  0.265286
# 19  barriers_to_access            use  0.166270

# %% [markdown]
# ### Helper Function to Clean Text
#
# This helper function removes non-ASCII characters from the text. This ensures clean tokenization and prevents issues during spaCy processing.

# %%
def remove_non_ascii(text):
    return text.encode("ascii", errors="ignore").decode("ascii")

# %% [markdown]
# ### Keywords In Context (KWIC) Function Definition
# This function, `kwic_spacy_multiple()`, is at the core of our analysis.
#
# It takes:
# - a list of documents,
# - a list of keywords,
# - and a context window size (default is 7 tokens to the left and right).
#
# For each keyword found in each document, it extracts:
# - the left context (up to N tokens),
# - the keyword itself,
# - and the right context (up to N tokens).
#
# This structure allows us to understand **how keywords are used in different contexts** across documents in a given theme.

# %%
def kwic_spacy_multiple(texts, keywords, window=7):
    tokenized_docs = []

    for doc in texts:
        spacy_doc = nlp(doc)
        tokens = [token.text for token in spacy_doc]
        tokenized_docs.append(tokens)

    results = []

    for tokens in tokenized_docs:
        for i, token in enumerate(tokens):
            for kw in keywords:
                if token.lower() == kw.lower():
                    left = tokens[max(i - window, 0) : i]
                    right = tokens[i + 1 : i + window + 1]
                    left_str = " ".join(left).replace("\n", " ").strip()
                    right_str = " ".join(right).replace("\n", " ").strip()
                    results.append((kw, left_str, token, right_str))
    return results

# %% [markdown]
# ### KWIC for Barriers to Access Theme
#
# Here we perform KWIC analysis for the "Barriers to Access" theme using:
# - the associated documents (with non-ASCII characters removed),
# - and its top 20 keywords.
#
# The resulting DataFrame (`barrier_to_access_kwic_df`) contains:
# - the keyword,
# - the context to its left and right,
# which will help us qualitatively explore how these keywords are used.

# %%
barrier_to_access_kwic_list = kwic_spacy_multiple(
    barrier_to_access["text"].astype(str).apply(remove_non_ascii).tolist(),
    barrier_to_access_keywords["keyword"].tolist(),
    window=7,
)

barrier_to_access_kwic_df = pd.DataFrame(
    barrier_to_access_kwic_list,
    columns=["Keyword Label", "Left Context", "Keyword", "Right Context"],
)
barrier_to_access_kwic_df.head(60)
# Out:
#     Keyword Label                                       Left Context  \
# 0          access            Persons With Disabilities   August 2020
# 1      accessible              and Scope   Results   Availability of
# 2      accessible          Sales Outlets   Promotion of Awareness of
# 3          mobile     Outlets   Promotion of Awareness of Accessible
# 4      accessible  Accessible Mobile Telecommunications   Procure...
# 5   accessibility  Procurement Policies on Accessible Handsets   ...
# 6      accessible  with Disabilities    Development and Availabil...
# 7   accessibility           of Discounted Rates for Telecom Services
# 8          mobile  Services   Accessibility and Awareness of Emer...
# 9          mobile                    Existence of Code of Conduct on
# 10  accessibility    of Code of Conduct on Mobile Telecommunications
# 11  communication  Muwonge Issa   Acknowledgements   Information and
# 12            ict  Acknowledgements   Information and Communicati...
# 13         access  of persons with disabilities through enabling ...
# 14         social             to   information , and enhancing their
# 15            use                 while a great number of people now
# 16            ict                   a great number of people now use
# 17         access                      in Africa still nd it hard to
# 18            use                           nd it hard to access and
# 19        digital                        it hard to access and   use
# 20        digital              continue to miss out on the potential
# 21            ict  with   disabilities faced inequality in accessing
# 22      assistive  disabilities faced inequality in accessing ICT...
# 23      assistive  inequality in accessing ICT and assistive tech...
# 24            use           are tools that persons with disabilities
# 25        include                 use to accomplish tasks , and they
# 26            use          , persons with disabilities are unable to
# 27        digital        persons with disabilities are unable to use
# 28        digital  digital technologies because   these technolog...
# 29  accessibility  technologies because   these technologies lack...
# 30         mobile                  namely the ability of a website ,
# 31        digital     , auditory , motor or cognitive disabilities.5
# 32  accessibility  auditory , motor or cognitive disabilities.5 D...
# 33         access     thus key to enabling persons with disabilities
# 34         social              the right to education , employment ,
# 35         access          steps to ensure that they have unfettered
# 36            ict     unfettered access to   quality information and
# 37        include             of persons with disabilities .   These
# 38         access     that allows persons with disabilities to fully
# 39         social                             market   ( SDG 8.5 ) ;
# 40     accessible                         SDG 10 ) ; creating safe ,
# 41        digital           disaggregated data ( SDG 17).8 Specic to
# 42         access         technologies , SDG 9c calls for increasing
# 43            ict                9c calls for increasing access   to
# 44       internet        to ICT and providing universal and aordable
# 45         access  ICT and providing universal and aordable internet
# 46            ict   .     Empowering Persons with Disability Through
# 47         access              ICTs for Persons   with Disability to
# 48         access                 and Uganda Must Do More to Improve
# 49            ict                  Must Do More to Improve Access to
# 50      assistive  Development Goals , https://www.un.org/develop...
# 51     technology  Goals , https://www.un.org/development/desa/di...
# 52        digital  Types of Assistive Technology , https://webacc...
# 53  accessibility  of Assistive Technology , https://webaccess.be...
# 54        digital      signicant obligations on countries to promote
# 55  accessibility  signicant obligations on countries to promote ...
# 56         access       ensure that   persons with disabilities have
# 57            ict           persons with disabilities have access to
# 58       internet                 have access to ICT , including the
# 59        service          governments to ensure that private sector
#
#           Keyword                                      Right Context
# 0          Access         Denied :   Introduction    Research Design
# 1      Accessible           Handsets in Sales Outlets   Promotion of
# 2      Accessible  Mobile Telecommunications   Procurement Polici...
# 3          Mobile  Telecommunications   Procurement Policies on A...
# 4      Accessible  Handsets   Physical Accessibility of Sales Out...
# 5   Accessibility            of Sales Outlets   Capacity of Telecoms
# 6      Accessible  Applications    Availability of Discounted Rat...
# 7   Accessibility   and Awareness of Emergency Mobile Communications
# 8          Mobile      Communications   Existence of Code of Conduct
# 9          Mobile  Telecommunications Accessibility   Discussion ...
# 10  Accessibility            Discussion of Key Findings   Conclusion
# 11  Communication            Technologies ( ICT ) have the potential
# 12            ICT             ) have the potential to make signicant
# 13         access             to   information , and enhancing their
# 14         social  and economic integration in communities by enl...
# 15            use                       ICT for   a growing range of
# 16            ICT                     for   a growing range of tasks
# 17         access                and   use digital technologies . As
# 18            use               digital technologies . As a result ,
# 19        digital                  technologies . As a result , they
# 20        digital                 dividends.2 Indeed , a 2018 United
# 21            ICT  and assistive technologies.3 Assistive technol...
# 22      assistive  technologies.3 Assistive technologies   are to...
# 23      Assistive         technologies   are tools that persons with
# 24            use             to accomplish tasks , and they include
# 25        include     screen   readers , screen magnication software
# 26            use  digital technologies because   these technolog...
# 27        digital  technologies because   these technologies lack...
# 28        digital            accessibility , namely the ability of a
# 29  accessibility                  , namely the ability of a website
# 30         mobile           application or electronic document to be
# 31        Digital            accessibility   is thus key to enabling
# 32  accessibility                    is thus key to enabling persons
# 33         access              information and services . It is also
# 34         social           services , and political participation .
# 35         access                 to   quality information and ICT ,
# 36            ICT                 , and are protected from all forms
# 37        include  inclusive learning environments and facilities...
# 38         access                         the job market   ( SDG 8.5
# 39         social           , economic and political inclusion ( SDG
# 40     accessible      , resilient   and sustainable communities and
# 41        digital         technologies , SDG 9c calls for increasing
# 42         access                 to ICT and providing universal and
# 43            ICT  and providing universal and aordable internet ...
# 44       internet    access .     Empowering Persons with Disability
# 45         access   .     Empowering Persons with Disability Through
# 46            ICT  , https://unesdoc.unesco.org/ark:/48223/pf0000...
# 47         Access  Information and Knowledge , https://unesdoc.un...
# 48         Access             to ICT for Persons with Disabilities ,
# 49            ICT  for Persons with Disabilities ,   https://cipe...
# 50      Assistive  Technology , https://webaccess.berkeley.edu/re...
# 51     Technology  , https://webaccess.berkeley.edu/resources/ass...
# 52        Digital  Accessibility , https://whatis.techtarget.com/...
# 53  Accessibility  , https://whatis.techtarget.com/denition/digit...
# 54        digital      accessibility and inclusion of persons   with
# 55  accessibility     and inclusion of persons   with disabilities.9
# 56         access                  to ICT , including the internet .
# 57            ICT          , including the internet . The Convention
# 58       internet                     . The Convention also calls on
# 59        service  providers also provide information and   services

# %% [markdown]
# ### KWIC for Digital Infrastructure Theme
#
# We now apply the same KWIC analysis process described earlier (see "Barriers to Access") to the **Digital Infrastructure** theme.
#
# This involves:
# - Preprocessing the text (cleaning non-ASCII characters),
# - Using spaCy to tokenize documents,
# - Extracting left and right contexts for the top 20 keywords.
#
# Then explore how keywords are used contextually in this theme’s documents.

# %%
digital_infrastructure_kwic_list = kwic_spacy_multiple(
    digital_infrastructure["text"].astype(str).apply(remove_non_ascii).tolist(),
    digital_infrastructure_keywords["keyword"].tolist(),
    window=7,
)

digital_infrastructure_kwic_df = pd.DataFrame(
    digital_infrastructure_kwic_list,
    columns=["Keyword Label", "Left Context", "Keyword", "Right Context"],
)
digital_infrastructure_kwic_df.head(50)
# Out:
#    Keyword Label                                       Left Context  \
# 0      household                                     2024 FinAccess
# 1         survey                         2024 FinAccess   Household
# 2         access                  2024 FinAccess   Household Survey
# 3          kenya                         However , CBK , KNBS , FSD
# 4          kenya                    this report .   Central Bank of
# 5      household    Kenya   Collaborating Partners   2024 FINACCESS
# 6         survey  Collaborating Partners   2024 FINACCESS HOUSEHOLD
# 7      household              HOUSEHOLD SURVEY   i   2024 FINACCESS
# 8         survey              SURVEY   i   2024 FINACCESS HOUSEHOLD
# 9         survey                         Economic Context   2   1.2
# 10        survey                        Survey Objectives   3   1.3
# 11        access                          and Methodology   3   2.0
# 12        access                                  ACCESS   10   2.1
# 13     Financial                                         10   2 . 2
# 14        access                             10   2 . 2   Financial
# 15     Financial                                         12   2 . 3
# 16        access                             12   2 . 3   Financial
# 17        access                         Access Overlaps   13   2.4
# 18        access                         by Demographics   14   2.5
# 19        access                                 by Sex    15   2.8
# 20        access                           by Livelihood   18   2.9
# 21        access                        Wealth Quintile   19   2.10
# 22       country                        by Demographics   23   2.12
# 23       service                               26   3.1    Usage by
# 24     Financial                                 QuAliTy   51   4.1
# 25     Financial                       63   5.2    Relevance of the
# 26     Financial             Devices / Solution for Dealing    With
# 27     Financial                               69   5.7   Trends in
# 28     Financial                          72   5.8   Perceptions on
# 29     household                            88   4   2024 FINACCESS
# 30        survey                  88   4   2024 FINACCESS HOUSEHOLD
# 31     household             HOUSEHOLD SURVEY   ii   2024 FINACCESS
# 32        survey             SURVEY   ii   2024 FINACCESS HOUSEHOLD
# 33     household    FINACCESS HOUSEHOLD SURVEY   The 2024 FinAccess
# 34        survey    HOUSEHOLD SURVEY   The 2024 FinAccess Household
# 35     Financial                     the 7th edition   based on the
# 36     inclusion               7th edition   based on the Financial
# 37        survey         edition   based on the Financial Inclusion
# 38        access          The report provides   key developments in
# 39     inclusion         quality and impact   dimensions of nancial
# 40     inclusion        like sustainable nance and investment   and
# 41     household       Persons with Disabilities .   2024 FINACCESS
# 42        survey     with Disabilities .   2024 FINACCESS HOUSEHOLD
# 43         kenya                         , MBS   Director General ,
# 44     Financial                            Ms. TaMara CooK   CEO ,
# 45         kenya          CEO , Financial Sector    Deepening Trust
# 46         kenya                  CBS    Governor , Central Bank of
# 47     household            pleased to present the 2024   FinAccess
# 48        survey          to present the 2024   FinAccess Household
# 49        survey               stakeholders .   This is the seventh
#
#       Keyword                                      Right Context
# 0   Household                  Survey   ACCESS   USAGE   QUALITY
# 1      Survey                           ACCESS   USAGE   QUALITY
# 2      ACCESS                           USAGE   QUALITY   IMPACT
# 3       Kenya                    and partners make no   claims ,
# 4       Kenya  Collaborating Partners   2024 FINACCESS HOUSEHOLD
# 5   HOUSEHOLD              SURVEY   i   2024 FINACCESS HOUSEHOLD
# 6      SURVEY                i   2024 FINACCESS HOUSEHOLD SURVEY
# 7   HOUSEHOLD                 SURVEY    CONTENTS   FOrEwOrd    v
# 8      SURVEY                           CONTENTS   FOrEwOrd    v
# 9      Survey                      Objectives   3   1.3   Survey
# 10     Survey                   Design and Methodology   3   2.0
# 11     ACCESS                               10   2.1   Access by
# 12     Access                           by Categories   10   2 .
# 13  Financial                        Access by Products   12   2
# 14     Access                             by Products   12   2 .
# 15  Financial                         Access Overlaps   13   2.4
# 16     Access                      Overlaps   13   2.4    Access
# 17     Access                         by Demographics   14   2.5
# 18     Access                                 by Sex    15   2.8
# 19     Access                           by Livelihood   18   2.9
# 20     Access                     by Wealth Quintile   19   2.10
# 21     Access                              by County   20   2.11
# 22    Country                    Comparison   25   3.0     uSAgE
# 23    Service                       Providers   26   3.2   Usage
# 24  Financial                    Literacy   49   4.2   Knowledge
# 25  Financial                        Sector in Meeting the Needs
# 26  Financial                      Needs    66   5.5   Financing
# 27  Financial                    Health   72   5.8   Perceptions
# 28  Financial                     Situation   75   5.9    Social
# 29  HOUSEHOLD             SURVEY   ii   2024 FINACCESS HOUSEHOLD
# 30     SURVEY               ii   2024 FINACCESS HOUSEHOLD SURVEY
# 31  HOUSEHOLD       SURVEY   The 2024 FinAccess Household Survey
# 32     SURVEY         The 2024 FinAccess Household Survey Report
# 33  Household                   Survey Report is the 7th edition
# 34     Survey                  Report is the 7th edition   based
# 35  Financial             Inclusion Survey . The report provides
# 36  Inclusion                 Survey . The report provides   key
# 37     Survey           . The report provides   key developments
# 38     access                       , usage , quality and impact
# 39  inclusion                       . The report also has delved
# 40  Inclusion             for Persons with Disabilities .   2024
# 41  HOUSEHOLD                SURVEY   iii   Dr. MaCDonalD oBuDHo
# 42     SURVEY                       iii   Dr. MaCDonalD oBuDHo ,
# 43      Kenya         National Bureau of Statistics   Ms. TaMara
# 44  Financial              Sector    Deepening Trust Kenya   Dr.
# 45      Kenya                             Dr. KaMau THuGGE , CBS
# 46      Kenya                               FOrEwOrd   W   e are
# 47  Household            Survey Topline   Findings Report to our
# 48     Survey      Topline   Findings Report to our stakeholders
# 49     Survey               since the 2006 baseline   Survey and

# %% [markdown]
# ###  KWIC Analysis for Inclusive Digital Technology Theme
#
# We now apply the same KWIC analysis process described earlier (see "Barriers to Access") to the **Inclusive Digital Technology** theme.
#
# This involves:
# - Preprocessing the text (cleaning non-ASCII characters),
# - Using spaCy to tokenize documents,
# - Extracting left and right contexts for the top 20 keywords.
#
# Then explore how keywords are used contextually in this theme’s documents.

# %%
inclusive_digital_technology_kwic_list = kwic_spacy_multiple(
    inclusive_digital_technology["text"].astype(str).apply(remove_non_ascii).tolist(),
    inclusive_digital_technology_keywords["keyword"].tolist(),
    window=7,
)

inclusive_digital_technology_kwic_df = pd.DataFrame(
    inclusive_digital_technology_kwic_list,
    columns=["Keyword Label", "Left Context", "Keyword", "Right Context"],
)
inclusive_digital_technology_kwic_df.head(50)
# Out:
#     Keyword Label                                       Left Context  \
# 0         digital                                     Theme : Taking
# 1   accessibility                             Theme : Taking Digital
# 2       assistive             Theme : Taking Digital Accessibility &
# 3      technology   Theme : Taking Digital Accessibility & Assistive
# 4          access                change and make generations to come
# 5           kenya       Njoki   Coordinator Short Stature Society of
# 6            need               be impaired by disability , thus the
# 7   accessibility              disability , thus the need to support
# 8   accessibility                         Vint Cerf , VP , and Chief
# 9   accessibility           Takeaways     Today we are talking about
# 10      inclusion                 journey . We will be talking about
# 11     technology           to persons with disabilities ; however ,
# 12           need                lifestyle is expensive due to their
# 13      assistive           due to their need for accommodations and
# 14          kenya                  's   Rights Office of President ,
# 15     technology                 Key Takeaways    For most people ,
# 16     technology                 , but for people with disability ,
# 17           need                     possible . There is a pressing
# 18      assistive                     . There is a pressing need for
# 19            use           need for assistive technologies .    The
# 20     technology             assistive technologies .    The use of
# 21     technology   technology such as screen reading , augmentative
# 22         access  participation among people living with disabil...
# 23          kenya                          and access is key .    In
# 24           need               government has put in place plans we
# 25  accessibility            importantly , humanity . Design enables
# 26           need              . Design enables   accessibility . We
# 27  accessibility                 make their   organization better .
# 28  accessibility                   .     Accessibility is Joy . Let
# 29      assistive  to the world .                                ...
# 30     technology  the world .                                   ...
# 31     innovation  world .                                       ...
# 32      assistive                   3 . Keoke King- CEO Participants
# 33      assistive      capital awareness and promote the adoption of
# 34      challenge                       At a global level , the main
# 35      assistive        the main challenge for entrepreneurs in the
# 36     technology  main challenge for entrepreneurs in the assistive
# 37           user                 , more funds should be invested in
# 38      assistive   uplift people 's differences   specialization in
# 39     innovation                        a key role in the future of
# 40     technology  disability awareness training can contribute t...
# 41          kenya           Muleka Founder & Managing of signs media
# 42  accessibility                 3 . Ayoolo Efunkoya : Journalist &
# 43  accessibility  Efunkoya : Journalist & Accessibility Enthusia...
# 44            use                , and government .     Widespread -
# 45        digital              and government .     Widespread - use
# 46      inclusion       plays a crucial role in promoting disability
# 47        digital                   overlooked in mainstream media .
# 48      challenge                 tell their own stories in order to
# 49     innovation                , USA   Key Takeaways     Brilliant
#
#           Keyword                                      Right Context
# 0         Digital  Accessibility & Assistive Technology in Africa to
# 1   Accessibility            & Assistive Technology in Africa to the
# 2       Assistive             Technology in Africa to the Next level
# 3      Technology                        in Africa to the Next level
# 4          access                          .    If we get together ,
# 5           Kenya                              ( SSSK )   6 . Julius
# 6            need        to support accessibility .     The Internet
# 7   accessibility                     .     The Internet needs to be
# 8   Accessibility           Evangelist Google   Key Takeaways    The
# 9   accessibility                and the various ways we can improve
# 10      inclusion               in political , social , and economic
# 11     technology                           can play a key   role in
# 12           need  for accommodations and assistive technologies ...
# 13      assistive    technologies . Paradoxically , their   economic
# 14          Kenya                   Key Takeaways    For most people
# 15     technology               makes things easier , but for people
# 16     technology                 makes things   possible . There is
# 17           need            for assistive technologies .    The use
# 18      assistive            technologies .    The use of technology
# 19            use             of technology such as screen reading ,
# 20     technology   such as screen reading , augmentative technology
# 21     technology       , etc . increase independent   participation
# 22         access                             is key .    In Kenya ,
# 23          Kenya                  , the government has put in place
# 24           need              to transform into policies and laws .
# 25  accessibility                       . We need to bring those two
# 26           need              to bring those two worlds together by
# 27  Accessibility                 is Joy . Let accessibility be your
# 28  accessibility                   be your love letter to the world
# 29      Assistive  Technology Innovation and Funding Panel   Spea...
# 30     Technology            Innovation and Funding Panel   Speakers
# 31     Innovation                   and Funding Panel   Speakers   1
# 32      Assistive                        Products   4 . Serena Davis
# 33      assistive               technologies , it is vital to create
# 34      challenge  for entrepreneurs in the assistive technology ...
# 35      assistive     technology industry is obtaining funding , and
# 36     technology                industry is obtaining funding , and
# 37           user            research to   deliver the best products
# 38      assistive            technologies is key .     Disability is
# 39     innovation                 in an accessible , inclusive , and
# 40     technology  .                                             ...
# 41          Kenya                      Limited   2 . Kesa Princely :
# 42  Accessibility     Enthusiast - Accessibility 360   Key Takeaways
# 43  Accessibility              360   Key Takeaways     Positive role
# 44            use     digital devices such as smartphones can become
# 45        digital           devices such as smartphones can become a
# 46      inclusion           in society . Governments , civil society
# 47        Digital             media has become a powerful outlet for
# 48      challenge  attitudes and   stereotypes surrounding disabi...
# 49     innovation  must everyone , including persons with disabil...

# %% [markdown]
# ###  KWIC Analysis for Tech EcoSystem Theme
#
# We now apply the same KWIC analysis process described earlier (see "Barriers to Access") to the **Tech EcoSystem** theme.
#
# This involves:
# - Preprocessing the text (cleaning non-ASCII characters),
# - Using spaCy to tokenize documents,
# - Extracting left and right contexts for the top 20 keywords.
#
# Then explore how keywords are used contextually in this theme’s documents.

# %%
tech_ecosystem_kwic_list = kwic_spacy_multiple(
    tech_ecosystem["text"].astype(str).apply(remove_non_ascii).tolist(),
    tech_ecosystem_keywords["keyword"].tolist(),
    window=7,
)

tech_ecosystem_kwic_df = pd.DataFrame(
    tech_ecosystem_kwic_list,
    columns=["Keyword Label", "Left Context", "Keyword", "Right Context"],
)
tech_ecosystem_kwic_df.head(50)  # display top 50 results
# Out:
#    Keyword Label                                       Left Context  \
# 0     employment                              Best Practices in the
# 1   intellectual                  in the Employment of Persons with
# 2           case       Persons with   Intellectual Disabilities : A
# 3         uganda        Intellectual Disabilities : A Case Study of
# 4         uganda                          ,   December 2022       1
# 5      inclusion  Uganda Association for the Mentally Handicapped /
# 6         uganda           for the Mentally Handicapped / Inclusion
# 7     employment                 Uganda       Best Practices in the
# 8   intellectual        Practices in the Employment of Persons with
# 9           case         Persons with Intellectual Disabilities : A
# 10        uganda                   Disabilities : A   Case Study of
# 11    employment  December 2022               Best Practices in the
# 12  intellectual                  in the Employment of Persons with
# 13          case       Persons with   Intellectual Disabilities : A
# 14        uganda        Intellectual Disabilities : A Case Study of
# 15          case                       1 . Executive Summary   This
# 16  intellectual        examines the barriers faced by persons with
# 17    employment  persons with intellectual disabilities in   ac...
# 18        uganda  intellectual disabilities in   accessing emplo...
# 19        sector           : employers from the formal and informal
# 20  intellectual                 and informal sector , persons with
# 21  intellectual                with 25 employers , 25 persons with
# 22      national          review looking at the   international and
# 23        policy        looking at the   international and national
# 24    employment            landscape , and research related to the
# 25  intellectual                to the employment of   persons with
# 26  intellectual    that the major barriers preventing persons with
# 27     inclusive  persons with intellectual disabilities   from ...
# 28    employment  with intellectual disabilities   from finding ...
# 29    employment                  to taking steps to   increase the
# 30  intellectual            increase the employment of persons with
# 31        uganda  employment of persons with intellectual disabi...
# 32    employment  Uganda .                                      ...
# 33  intellectual                  in the Employment of Persons with
# 34          case       Persons with   Intellectual Disabilities : A
# 35        uganda        Intellectual Disabilities : A Case Study of
# 36    employment                6   3.1   International Policies on
# 37      national  on Employment ...................................
# 38    employment                     6   3.2   National Policies on
# 39    employment  .................................................
# 40        uganda      on Employment of Persons with Disabilities in
# 41  intellectual             3.4   Challenges Faced by Persons with
# 42  intellectual                 4.4   Perspectives of Persons with
# 43  intellectual                        13   5.3   For Persons with
# 44        policy  Disabilities ....................................
# 45    employment  .................................................
# 46  intellectual                  in the Employment of Persons with
# 47          case       Persons with   Intellectual Disabilities : A
# 48        uganda        Intellectual Disabilities : A Case Study of
# 49    employment                               4   2 . Introduction
#
#          Keyword                                      Right Context
# 0     Employment      of Persons with   Intellectual Disabilities :
# 1   Intellectual              Disabilities : A Case Study of Uganda
# 2           Case                  Study of Uganda ,   December 2022
# 3         Uganda                          ,   December 2022       1
# 4         Uganda  Association for the Mentally Handicapped / Inc...
# 5      Inclusion                 Uganda       Best Practices in the
# 6         Uganda                Best Practices in the Employment of
# 7     Employment      of Persons with Intellectual Disabilities : A
# 8   Intellectual                   Disabilities : A   Case Study of
# 9           Case                    Study of Uganda     Prepared by
# 10        Uganda                       Prepared by    Aida Nanyonjo
# 11    Employment      of Persons with   Intellectual Disabilities :
# 12  Intellectual              Disabilities : A Case Study of Uganda
# 13          Case                  Study of Uganda ,   December 2022
# 14        Uganda                          ,   December 2022       2
# 15          case        study report examines the barriers faced by
# 16  intellectual   disabilities in   accessing employment in Uganda
# 17    employment         in Uganda . The study employed qualitative
# 18        Uganda        . The study employed qualitative methods of
# 19        sector     , persons with   Intellectual disabilities and
# 20  Intellectual    disabilities and their Parents/ guardians . The
# 21  intellectual     disabilities and 30 parents and/or guardians .
# 22      national         policy landscape , and research related to
# 23        policy            landscape , and research related to the
# 24    employment      of   persons with intellectual disabilities ;
# 25  intellectual           disabilities ; a summary of the research
# 26  intellectual  disabilities   from finding inclusive employme...
# 27     inclusive               employment are a lack of education ,
# 28    employment                   are a lack of education , social
# 29    employment  of persons with intellectual disabilities in U...
# 30  intellectual  disabilities in Uganda .                      ...
# 31        Uganda  .                                      Best Pr...
# 32    Employment      of Persons with   Intellectual Disabilities :
# 33  Intellectual              Disabilities : A Case Study of Uganda
# 34          Case                  Study of Uganda ,   December 2022
# 35        Uganda                          ,   December 2022       3
# 36    Employment  .................................................
# 37      National  Policies on Employment ..........................
# 38    Employment  .................................................
# 39    Employment  of Persons with Disabilities in Uganda ..........
# 40        Uganda  ................................ 8   3.4   Cha...
# 41  Intellectual  Disabilities ....................................
# 42  Intellectual  Disabilities ....................................
# 43  Intellectual  Disabilities ....................................
# 44        Policy  Makers ..........................................
# 45    Employment      of Persons with   Intellectual Disabilities :
# 46  Intellectual              Disabilities : A Case Study of Uganda
# 47          Case                  Study of Uganda ,   December 2022
# 48        Uganda                          ,   December 2022       4
# 49    Employment                        in Uganda is life , but why

# %% [markdown]
# ###  KWIC Analysis for Case Studies Theme
#
# We now apply the same KWIC analysis process described earlier (see "Barriers to Access") to the **Case Studies** theme.
#
# This involves:
# - Preprocessing the text (cleaning non-ASCII characters),
# - Using spaCy to tokenize documents,
# - Extracting left and right contexts for the top 20 keywords.
#
# Then explore how keywords are used contextually in this theme’s documents.

# %%
case_studies_kwic_list = kwic_spacy_multiple(
    case_studies["text"].astype(str).apply(remove_non_ascii).tolist(),
    case_studies_keywords["keyword"].tolist(),
    window=7,
)

case_studies_kwic_df = pd.DataFrame(
    case_studies_kwic_list,
    columns=["Keyword Label", "Left Context", "Keyword", "Right Context"],
)
case_studies_kwic_df.head(50)  # display top 50 results
# Out:
#    Keyword Label                                      Left Context  \
# 0        student      Returns to Inspire Students   former Pacelli
# 1        digital   Inspire Students   former Pacelli student leads
# 2         school       Akinola walked the corridors of the Pacelli
# 3        student       Partially Sighted Children in Surulere as a
# 4        student                          , he returned , not as a
# 5      assistive   empowering individuals with vision loss through
# 6     technology  individuals with vision loss through   assistive
# 7        digital    vision loss through   assistive technology and
# 8      assistive                   provided over $ 26,000 worth of
# 9        digital            trained more than 200 blind persons in
# 10     inclusion    former member of several global disability and
# 11     education       Union and the International Council for the
# 12       digital               of the key speakers at MTN Nigerias
# 13       digital    aimed to equip visually impaired students with
# 14       company                             I m the CEO of my own
# 15     assistive       character recognition tools to AI - powered
# 16       digital   assistive technologies , emphasising that   the
# 17     inclusive                the digital world is becoming more
# 18       digital            filled   with impactful moments , from
# 19     inclusive      opening discussions about the   potential of
# 20    technology    discussions about the   potential of inclusive
# 21       company                  messages of hope . Uto Ukpanah ,
# 22       digital                 theme Connecting at   the Roots :
# 23    technology            the most powerful women   in financial
# 24        riziki                study   Founded by Fredrick Ouko ,
# 25        source                 Founded by Fredrick Ouko , Riziki
# 26           job             in Kenya with a mission to facilitate
# 27       support               . Additionally , they offer ongoing
# 28     inclusion                   , and   myths that hinder their
# 29        riziki            change ,   Fredrick Ouko established '
# 30        source            ,   Fredrick Ouko established ' Riziki
# 31        riziki                            in   2015 . The term '
# 32        source                          2015 . The term ' Riziki
# 33        riziki                   signifying " livelihood . "   '
# 34        source                       " livelihood . "   ' Riziki
# 35     inclusion           to nd suitable candidates ,   promoting
# 36        riziki                     in the   Innovate Now Program
# 37        source               the   Innovate Now Program   Riziki
# 38       support                        Cohort 3 , aimed to secure
# 39        riziki      attract   strategic partners and investors .
# 40        source         strategic partners and investors . Riziki
# 41       company        community   Background   Furthermore , the
# 42        riziki         The programme played a signicant role for
# 43        source                played a signicant role for Riziki
# 44   opportunity               Source as it provided them a unique
# 45        riziki                which was   the only platform that
# 46        source               was   the only platform that Riziki
# 47        riziki              This   hands - on experience allowed
# 48        source              hands - on experience allowed Riziki
# 49           job   serve , individuals with disabilities   seeking
#
#         Keyword                                      Right Context
# 0       student      leads digital skills training for Y'ello Care
# 1       digital          skills training for Y'ello Care     Years
# 2        School                for the Blind   & Partially Sighted
# 3       student           with big dreams and uncertain   pathways
# 4       student                                 , but as a CEO , a
# 5     assistive           technology and digital skills training .
# 6    technology            and digital skills training .     Since
# 7       digital           skills training .     Since launching in
# 8     assistive               tech and trained more than 200 blind
# 9       digital           literacy , from foundation to   advanced
# 10    inclusion                 bodies , including the World Blind
# 11    Education                   of   Visually Impaired Persons .
# 12      Digital              Upskilling Bootcamp held as   part of
# 13      digital            skills and   inspiration for the future
# 14      company                      . Start learning   now so you
# 15    assistive      technologies , emphasising that   the digital
# 16      digital              world is becoming more inclusive . He
# 17    inclusive                    . He urged the students to take
# 18      digital       skills sessions to eye - opening discussions
# 19    inclusive              technology .   Other MTN leaders also
# 20   technology                  .   Other MTN leaders also shared
# 21      Company                Secretary , MTN   Nigeria , offered
# 22      Digital      Tools for Connected Communities , focusing on
# 23   technology                on the continent with over 16 years
# 24       Riziki                  Source , is a social   enterprise
# 25       Source                      , is a social   enterprise in
# 26          job  accessibility for individuals with disabilities .
# 27      support       to these entities in the recruitment process
# 28    inclusion                 in   workplaces worldwide . One of
# 29       Riziki                           Source ' in   2015 . The
# 30       Source                             ' in   2015 . The term
# 31       Riziki                     Source ' is derived from   the
# 32       Source                    ' is derived from   the Swahili
# 33       Riziki                       Source ' serves as an online
# 34       Source                   ' serves as an online   platform
# 35    inclusion                 and diversity in the   workforce .
# 36       Riziki            Source application for the Innovate Now
# 37       Source     application for the Innovate Now   Accelerator
# 38      support               in validating and rening their value
# 39       Riziki     Source also   sought assistance in structuring
# 40       Source      also   sought assistance in structuring their
# 41      company           also sought structured   ways to connect
# 42       Riziki                       Source as it provided them a
# 43       Source           as it provided them a unique opportunity
# 44  opportunity               to engage directly with their target
# 45       Riziki                        Source had . This   hands -
# 46       Source                            had . This   hands - on
# 47       Riziki          Source to   gather valuable feedback from
# 48       Source             to   gather valuable feedback from the
# 49          job          opportunities .   The advice and insights
