# %% [markdown]
# # Text Cleaning and Preprocessing Pipeline for **PDF Text Data**
#
# This notebook extracts and preprocesses textual data from PDF files using **PyMuPDF** for extraction and **spaCy** for processing and cleaning.
# The cleaned text is organized and exported for use in NLP tasks such as keyword extraction, topic modeling, and qualitative validation.

# %% [markdown]
# ## Step 1: Import & Load Dependencies
#
# We import all required Python libraries used throughout the notebook. These include:
#
# - `fitz` from PyMuPDF – for PDF reading and text extraction.
# - `spacy` – for natural language processing and text cleaning.
# - `pandas` – for working with structured tabular data.

# %%
import spacy
import fitz
import pandas as pd

# %% [markdown]
# ## Step 2: List the PDF Files to Process
#
# In this step, we use Python’s `pathlib.Path` to navigate the file system and locate all PDF files within the target dataset folder.
#
# The `Path` object provides an easy and readable way to:
# - Set the directory to search (e.g., `Path("../1_datasets")`).
# - Recursively search for all files ending in `.pdf` using `.rglob("*.pdf")`.
#
# For each PDF file found, we create a dictionary containing:
# - The file name,
# - The full file path (as a `Path` object),
# - The theme (based on directory name).
#
# This structured list of dictionaries allows us to track the necessary information and apply consistent preprocessing in the following steps.

# %%
from pathlib import Path

# Relative path to the dataset folder
datasets_folder = Path.cwd().parent / "1_datasets"
raw_text_data = []

# Recursively search for all PDF files in subdirectories
for pdf_path in datasets_folder.rglob("*.pdf"):
    raw_text_data.append(
        {
            "name": pdf_path.stem,  # filename without extension
            "theme": pdf_path.parent.name,  # name of the immediate parent folder
            "path": str(pdf_path),  # path to pdf file for later processing
        }
    )

raw_text_data
# Out:
# [{'name': 'Access Denied',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/Access Denied.pdf'},
#  {'name': 'Accessibility to digital technology',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/Accessibility to digital technology.pdf'},
#  {'name': 'Bridging the digital divide',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/Bridging the digital divide.pdf'},
#  {'name': 'ICT and Disability',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/ICT and Disability.pdf'},
#  {'name': 'Mobile Disability Gap Report 2021',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/Mobile Disability Gap Report 2021.pdf'},
#  {'name': 'Social protection and access to assistive technolo',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/Social protection and access to assistive technolo.pdf'},
#  {'name': 'Strengthening ICT Accessibility for PWDs in Africa',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/Strengthening ICT Accessibility for PWDs in Africa.pdf'},
#  {'name': 'The Millions of Nigerians Whose Use of Technology is an Afterthought',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/The Millions of Nigerians Whose Use of Technology is an Afterthought.pdf'},
#  {'name': 'The State of Digital Inclusion in Africa',
#   'theme': 'barriers_to_access',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/barriers_to_access/The State of Digital Inclusion in Africa.pdf'},
#  {'name': 'Akinola Opeolu',
#   'theme': 'case_studies',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/case_studies/Akinola Opeolu.pdf'},
#  {'name': 'Farida Bedwei',
#   'theme': 'case_studies',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/case_studies/Farida Bedwei.pdf'},
#  {'name': 'Fredrick Ouko',
#   'theme': 'case_studies',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/case_studies/Fredrick Ouko.pdf'},
#  {'name': 'Innovating Inclusion',
#   'theme': 'case_studies',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/case_studies/Innovating Inclusion.pdf'},
#  {'name': 'Nafisa Baboo',
#   'theme': 'case_studies',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/case_studies/Nafisa Baboo.pdf'},
#  {'name': 'Papi Sibomana',
#   'theme': 'case_studies',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/case_studies/Papi Sibomana.pdf'},
#  {'name': '2024 FinAccess Household Survey',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/2024 FinAccess Household Survey.pdf'},
#  {'name': 'Accelerating digital inclusion in Africa',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/Accelerating digital inclusion in Africa.pdf'},
#  {'name': 'An-Assessment-of-Digital-Inclusion-among-the-Vulnerable-Persons-in-Developing-Economies',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/An-Assessment-of-Digital-Inclusion-among-the-Vulnerable-Persons-in-Developing-Economies.pdf'},
#  {'name': 'Assessing-the-Brriers-to-Accessing-ICT-by-Persons-With-Disabilities-in-Kenya',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/Assessing-the-Brriers-to-Accessing-ICT-by-Persons-With-Disabilities-in-Kenya.pdf'},
#  {'name': 'Digital Transformation Drives Development in Africa',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/Digital Transformation Drives Development in Africa.pdf'},
#  {'name': "fostering Digital Inclusion Among Nigeria's Persons With Disabilities",
#   'theme': 'digital_infrastructure',
#   'path': "/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/fostering Digital Inclusion Among Nigeria's Persons With Disabilities.pdf"},
#  {'name': 'New Insights on Mobile Internet Connectivity in SSA',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/New Insights on Mobile Internet Connectivity in SSA.pdf'},
#  {'name': 'platform Livelihoods For Kenyan Youth With Disabilities,A Survey And Qualitative Study',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/platform Livelihoods For Kenyan Youth With Disabilities,A Survey And Qualitative Study.pdf'},
#  {'name': 'Size and Distribution of Digital Connectivity Gaps in SSA',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/Size and Distribution of Digital Connectivity Gaps in SSA.pdf'},
#  {'name': 'The mobile disability gap,how do persons with disabilities access and use mobile in Kenya and Bangladesh (2)',
#   'theme': 'digital_infrastructure',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/digital_infrastructure/The mobile disability gap,how do persons with disabilities access and use mobile in Kenya and Bangladesh (2).pdf'},
#  {'name': 'Accessibility and Digital Inclusion Knowledge Document',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/Accessibility and Digital Inclusion Knowledge Document.pdf'},
#  {'name': 'AI Assistive Technologies for Persons with Disabilities in Africa',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/AI Assistive Technologies for Persons with Disabilities in Africa.pdf'},
#  {'name': 'AI for Inclusive Development in Africa (AT2030 Report)',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/AI for Inclusive Development in Africa (AT2030 Report).pdf'},
#  {'name': 'Digital Inclusion Practices & Technology Accessibility in Nairobi',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/Digital Inclusion Practices & Technology Accessibility in Nairobi.pdf'},
#  {'name': 'Disability Is Not Inability',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/Disability Is Not Inability.pdf'},
#  {'name': 'Empowering PWD through Digital Innovation',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/Empowering PWD through Digital Innovation.pdf'},
#  {'name': 'How Can AI Assist African Disabled To Be Business Owners and Entrepreneurs',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/How Can AI Assist African Disabled To Be Business Owners and Entrepreneurs.pdf'},
#  {'name': 'Usability and Digital Accessibility Reports',
#   'theme': 'inclusive_digital_technology',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/inclusive_digital_technology/Usability and Digital Accessibility Reports.pdf'},
#  {'name': 'Best Practices in the Employment of Persons with Intellectual Disabilities',
#   'theme': 'tech_ecosystem',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/tech_ecosystem/Best Practices in the Employment of Persons with Intellectual Disabilities.pdf'},
#  {'name': 'Empowering Vulnerable Communities',
#   'theme': 'tech_ecosystem',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/tech_ecosystem/Empowering Vulnerable Communities.pdf'},
#  {'name': 'Inside Opeoluwa Akinola’s mission to empower PWD',
#   'theme': 'tech_ecosystem',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/tech_ecosystem/Inside Opeoluwa Akinola’s mission to empower PWD.pdf'},
#  {'name': 'Safaricom PLC Disability Inclusion',
#   'theme': 'tech_ecosystem',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/tech_ecosystem/Safaricom PLC Disability Inclusion.pdf'},
#  {'name': 'Sightsavers Inclusive Data 2024 Annual Review',
#   'theme': 'tech_ecosystem',
#   'path': '/Volumes/Adata su650 512gb/C/karim/ET6-CDSP-group-24-repo/1_datasets/tech_ecosystem/Sightsavers Inclusive Data 2024 Annual Review.pdf'}]

# %% [markdown]
# ## Step 3: Extract Raw Text from Each PDF
#
# Using `PyMuPDF`, we extract raw textual content from each PDF, page by page. This is done through a helper function that:
#
# - Opens the PDF file
# - Iterates through its pages
# - Extracts plain text content from each page
# - And combines it into a single string per document
#
# The resulting text is stored back into the list of dictionaries under the `'cleaned_text'` key.

# %%
def extract_text_from_pdf(pdf_path):
    """
    Extracts all text from a PDF file using PyMuPDF.

    Args:
        pdf_path (str): Path to the PDF file.

    Returns:
        str: Extracted text from the PDF.
    """
    text = ""
    with fitz.open(pdf_path) as doc:
        for page in doc:
            text += page.get_text()
    return text

# %% [markdown]
# ## Step 4: Clean and Normalize Extracted Text Using spaCy
#
# In this step, we use `spaCy`'s English language model (`en_core_web_sm`) to clean and normalize the raw text extracted from the PDFs.
#
# Each text entry is processed through a custom function that:
# - Tokenizes the text into individual words and symbols.
# - Removes stopwords (common words like "the", "and", "of" that carry little meaning).
# - Filters out punctuation, less than 3 digits, and whitespace-only tokens.
# - Retains only alphabetic words (e.g., no numbers or symbols).
# - Converts tokens to lowercase for uniformity.
#
# The result is a cleaned version of the text that preserves meaningful words, which is better suited for NLP tasks such as keyword extraction, topic modeling, or qualitative analysis.

# %%
nlp = spacy.load("en_core_web_sm")


def clean_text(text):
    doc = nlp(text)
    return " ".join(
        token.lemma_.lower()
        for token in doc
        if not token.is_stop
        and not token.is_punct
        and not token.like_url
        and not token.like_email
        and not token.is_space
        and not (token.is_digit and len(token.text) < 3)
    )

# %% [markdown]
# ## Step 5: Store Cleaned Text into the Dataset
#
# Here we iterate through the list of PDF records and apply the text cleaning function from Step 4. The cleaned output is added as a new key-value pair (`'cleaned_text'`) to each dictionary.
#
# This allows us to retain both the raw and cleaned versions of each document in the same structure.

# %%
for item in raw_text_data:
    try:
        raw = clean_text(extract_text_from_pdf(item["path"]))
        item["cleaned_text"] = clean_text(raw)
    except Exception as e:
        item["cleaned_text"] = None
        print(f"Error with {item['path']}: {e}")

# %% [markdown]
# ## Step 6: Convert Data into a Structured DataFrame
# We now convert the cleaned dictionary into a pandas DataFrame for easier handling and export.

# %%
cleaned_datasets_df = pd.DataFrame(
    raw_text_data, columns=["name", "theme", "cleaned_text"]
)

cleaned_datasets_df
# Out:
#                                                  name  \
# 0                                       Access Denied
# 1                 Accessibility to digital technology
# 2                         Bridging the digital divide
# 3                                  ICT and Disability
# 4                   Mobile Disability Gap Report 2021
# 5   Social protection and access to assistive tech...
# 6   Strengthening ICT Accessibility for PWDs in Af...
# 7   The Millions of Nigerians Whose Use of Technol...
# 8            The State of Digital Inclusion in Africa
# 9                                      Akinola Opeolu
# 10                                      Farida Bedwei
# 11                                      Fredrick Ouko
# 12                               Innovating Inclusion
# 13                                       Nafisa Baboo
# 14                                      Papi Sibomana
# 15                    2024 FinAccess Household Survey
# 16           Accelerating digital inclusion in Africa
# 17  An-Assessment-of-Digital-Inclusion-among-the-V...
# 18  Assessing-the-Brriers-to-Accessing-ICT-by-Pers...
# 19  Digital Transformation Drives Development in A...
# 20  fostering Digital Inclusion Among Nigeria's Pe...
# 21  New Insights on Mobile Internet Connectivity i...
# 22  platform Livelihoods For Kenyan Youth With Dis...
# 23  Size and Distribution of Digital Connectivity ...
# 24  The mobile disability gap,how do persons with ...
# 25  Accessibility and Digital Inclusion Knowledge ...
# 26  AI Assistive Technologies for Persons with Dis...
# 27  AI for Inclusive Development in Africa (AT2030...
# 28  Digital Inclusion Practices & Technology Acces...
# 29                        Disability Is Not Inability
# 30          Empowering PWD through Digital Innovation
# 31  How Can AI Assist African Disabled To Be Busin...
# 32        Usability and Digital Accessibility Reports
# 33  Best Practices in the Employment of Persons wi...
# 34                  Empowering Vulnerable Communities
# 35   Inside Opeoluwa Akinola’s mission to empower PWD
# 36                 Safaricom PLC Disability Inclusion
# 37      Sightsavers Inclusive Data 2024 Annual Review
#
#                            theme  \
# 0             barriers_to_access
# 1             barriers_to_access
# 2             barriers_to_access
# 3             barriers_to_access
# 4             barriers_to_access
# 5             barriers_to_access
# 6             barriers_to_access
# 7             barriers_to_access
# 8             barriers_to_access
# 9                   case_studies
# 10                  case_studies
# 11                  case_studies
# 12                  case_studies
# 13                  case_studies
# 14                  case_studies
# 15        digital_infrastructure
# 16        digital_infrastructure
# 17        digital_infrastructure
# 18        digital_infrastructure
# 19        digital_infrastructure
# 20        digital_infrastructure
# 21        digital_infrastructure
# 22        digital_infrastructure
# 23        digital_infrastructure
# 24        digital_infrastructure
# 25  inclusive_digital_technology
# 26  inclusive_digital_technology
# 27  inclusive_digital_technology
# 28  inclusive_digital_technology
# 29  inclusive_digital_technology
# 30  inclusive_digital_technology
# 31  inclusive_digital_technology
# 32  inclusive_digital_technology
# 33                tech_ecosystem
# 34                tech_ecosystem
# 35                tech_ecosystem
# 36                tech_ecosystem
# 37                tech_ecosystem
#
#                                          cleaned_text
# 0   telecom operators africa fail person disabilit...
# 1   term condition access use find assistive techn...
# 2   vol.:(0123456789 discover global society 2025 ...
# 3   information communication technology ict disab...
# 4   mobile disability gap report 2021 mobile disab...
# 5   term condition access use find assistive techn...
# 6   strengthen ict accessibility pwd africa post n...
# 7   assistive tech leave million nigerian use tech...
# 8   state digital inclusion africa challenge disab...
# 9   blind tech ceo return inspire student pacelli ...
# 10  person disability usually portray feeble want ...
# 11  unlock human potential innovate case study fin...
# 12  innovate inclusion youth disability lead futur...
# 13  transform education begin inclusion  general ...
# 14  man disability catalyst innovation papi siboma...
# 15  2024 finaccess household survey access usage q...
# 16  accelerate digital inclusion africa editor not...
# 17  assessment digital inclusion vulnerable person...
# 18  january 2021 disability kenya access ict peopl...
# 19  digital transformaɵon drive development africa...
# 20  foster digital inclusion nigeria person disabi...
# 21  new insight mobile internet connectivity sub s...
#  kenyan youth disability ...
# 23  size distribution digital connectivity gap sub...
# 24  mobile disability gap person disability access...
# 25  theme digital accessibility assistive technolo...
# 26  ai assistive technology at person disability p...
# 27  at2030 report june 2024 fund research lead rep...
# 28  international academic journal economics finan...
# 29  disability inability address disability divide...
# 30  empower person disability digital innovation i...
# 31  mon feb 2025 feature article ai assist african...
# 32  usability test digital accessibility complianc...
# 33  good practice employment person intellectual d...
# 34  empower vulnerable community mtn commitment in...
# 35  assistive tech screen reader audio describe so...
# 36  safaricom plc safaricom commit drive digital i...
# 37  advance inclusive datum sightsaver 2024 annual...

# %% [markdown]
# ## Step 7: Export Cleaned Data to CSV
#
# The final cleaned DataFrame is exported as `cleaned_datasets.csv` to the `/1_datasets` directory.
#
# It serves as the starting point for downstream NLP workflows like keyword extraction, topic modeling, or annotation.

# %%
cleaned_datasets_df.to_csv(
    "../1_datasets/processed_data/cleaned_datasets.csv", index=False
)

# %% [markdown]
# ## Next Steps
# - Use the cleaned CSV for topic modeling, keyword extraction, or any qualitative coding.
